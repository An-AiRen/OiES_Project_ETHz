# %% [markdown]
# Implement the demand response

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
import matplotlib.pyplot as plt

# %% [markdown]
# Function collection

# %%
def extract_cyc(profile) -> tuple:
    """
    Extract the operation cycles from the profile.
    Returns the start times and profile of the cycles.
    """
    cycles = [] # list of operation cycles
    cycle = [] # current operation cycle
    for i in range(len(profile)):
        if profile[i] > 0:
            cycle.append(i)
        else: # if the profile is 0, it means the cycle is over
            if cycle:
                cycles.append(cycle)
                cycle = []
    if cycle:
        cycles.append(cycle)
        
    return [c[0] for c in cycles], [profile[c] for c in cycles]

def constrain_nonflex(model, cycle_start, cycle_profile, duration, tolerance, name: str):
    """
    Build the optimization constraints for the non-flexible appliances.
    """
    # Create variables
    num_cycle = len(cycle_start)

    app_energy = model.addVars(num_cycle, duration, vtype=gp.GRB.CONTINUOUS, lb=0, name=name+"_power")
    app_start = model.addVars(num_cycle, duration, vtype=gp.GRB.BINARY, name=name+"_start")

    for i, start in enumerate(cycle_start):
        len_cycle = len(cycle_profile[i])
        # constraint (1)&(2): The starting time of each operation should not deviate from the consumer preference
        # time by more than a certain time tolerance. I think it doesn't make any sense to bring the operation ahead
        # of the preference time, so we only consider the delay.
        model.addConstr(gp.quicksum(app_start[i, j] for j in range(start, start + tolerance[i] + 1)) == 1, name=name+f"_start_constr_{i}")

        # constraint: all the operations should complete before the end of the day
        model.addConstr(gp.quicksum(app_start[i, j] for j in range(start, duration-len_cycle+1)) == 1, name=name+f"end_constr_{i}")

        # constraint: every operation should only start once
        model.addConstr(gp.quicksum(app_start[i, j] for j in range(duration)) == 1, name=name+f"_unique_constr_{i}")

        # constraint (3): the operation should not start before the end of the previous operation
        if i > 0:
            model.addConstr(gp.quicksum((app_start[i, j]-app_start[i-1, j])*j for j in range(start, start + tolerance[i] + 1)) >= len_cycle, name=name+f"_overlap_constr_{i}")
        # constraint (4): the shifted operation is calculated as the convolution of the profile and the decision variable
        for j in range(duration):
            conv = gp.quicksum(app_start[i, j-k] * cycle_profile[i][k] for k in range(len_cycle) if j-k >= 0)
            model.addConstr(app_energy[i, j] == conv, name=f"wm_power_constr_{i}_{j}")

    return app_energy, app_start

def constrain_flex(model, soc_init, soc_demand, soc_max, pos_rate, neg_rate, eff, t_in, t_out, duration, name: str):
    """
    Build the optimization constraints for the flexible appliances.
    """
    # constraint (6): the power rate is limited by the maximum charging and discharging power rate
    app_pos_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, ub=pos_rate, name=name+"_pos_power")
    app_neg_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=neg_rate, ub=0, name=name+"_neg_power")

    # assume the lower bound of soc is internally higher than 0 
    app_soc = model.addVars(t_out-t_in+1, vtype=gp.GRB.CONTINUOUS, lb=0, ub=soc_max, name=name+"_soc")

    # constraint (5): the energy demand has to be satisfied within the time window [plug_in, plug_out]
    model.addConstr(app_soc[t_out-t_in] - soc_init == soc_demand, name=name+"_demand_constr")
    # constraint: the initial state of charge is set to the initial value
    model.addConstr(app_soc[0] == soc_init, name=name+f"_soc_init_constr")

    for t in range(duration):
        if t < t_in or t >= t_out:
            # constraint (7): the power rate is limited to 0 outside the time window [plug_in, plug_out]
            model.addConstr(app_pos_energy[t] == 0, name=name+f"_pos_power_constr_{t}")
            model.addConstr(app_neg_energy[t] == 0, name=name+f"_neg_power_constr_{t}")
        
        # transition function of the state of charge
        else:
            model.addConstr(app_soc[t-t_in+1] == app_soc[t-t_in] + app_pos_energy[t]*eff + app_neg_energy[t]/eff, name=name+f"_soc_pos_constr_{t}") 
            model.addConstr(app_pos_energy[t] * app_neg_energy[t] == 0, name=name+f"_pos_neg_constr_{t}") # only one of the two can be non-zero
    
    return app_pos_energy, app_neg_energy, app_soc 

def constrain_pv(model, battery_init, battery_max, energy_rate, eff, duration, name: str):
    """
    Build the optimization constraints for the PV system.
    """
    battery_pos_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, ub=energy_rate, name=name+"_pos_battery_charge") 
    battery_neg_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=-energy_rate, ub=0, name=name+"_neg_battery_charge") 
    battery_soc = model.addVars(duration+1, vtype=gp.GRB.CONTINUOUS, lb=0, ub=battery_max, name=name+"battery_soc")

    # initialize the battery soc
    model.addConstr(battery_soc[0] == battery_init, name=name+"_battery_soc_init")
    # model.addConstr(battery_soc[duration] == battery_init, name=name+"_battery_soc_end")
    for t in range(duration):
        # transition function of soc
        model.addConstr(battery_soc[t+1] == battery_pos_energy[t]*eff + battery_neg_energy[t]/eff + battery_soc[t], name=name+f"_battery_soc_constr_{t}")

        # constraint: the aggregation of total demand and energy charged into the battery should be greater than pv
        # model.addConstr(pv_pred[t] - demand[t] <= battery_pos_energy[t] + battery_neg_energy[t], name=name+f"_battery_pv_{t}")
        # constraint: at each time step, the battery can only charge or discharge
        model.addConstr(battery_pos_energy[t] * battery_neg_energy[t] == 0, name=name+f"_battery_pos_neg_constr_{t}")

    return battery_pos_energy, battery_neg_energy, battery_soc

def get_profile(var, row, col, type='nonflex'):
    """
    Get the profile of a gurobi variable.
    row: number of cycles
    col: number of time steps
    """
    if type == 'nonflex':
        return [sum(var[i, t].X for i in range(row)) for t in range(col)]
    
    if type == 'flex':
        return [var[t].X for t in range(col)]

def get_tolerance(cyc_start, cyc_profile, duration, max_delay=24):
    """
    Get the tolerance for the operation cycles.
    The tolerance is the maximum delay allowed for each cycle.
    """
    tolerance = [] # list of tolerances for each cycle
    n_cyc = len(cyc_start) # number of cycles

    if n_cyc == 0:
        return tolerance
    
    for i in range(n_cyc-1):
        len_cyc = len(cyc_profile[i])
        gap = cyc_start[i+1] - (cyc_start[i] + len_cyc)
        if gap > max_delay: # maximum tolerance is 6 hours
                tolerance.append(max_delay)
        else:
                tolerance.append(gap)
    # the last cycle can be delayed until the end of the day
    len_cyc = len(cyc_profile[-1])
    gap = duration - (cyc_start[-1] + len_cyc) 
    if gap > max_delay:
        tolerance.append(max_delay)
    else:
        tolerance.append(gap)
    
    return tolerance

# %% [markdown]
# load the houldhold data and the dynamic price

# %%
household = pd.read_csv('winter_household_energydata.csv', index_col=0)
duration = 24 * 4  # 24 hours, 15 minutes per time step per day
n_days = household.shape[0] // duration

# initial time series
critical_tot = np.array(household['Critical Appliances'])
wm_tot = np.array(household['Washing Machine'])
dishwasher_tot = np.array(household['Dishwasher'])
pv_tot = np.array(household['PV']) # The assumption is that our prediction of pv generation is 100% accurate
price = np.array(household['Dynamic Price']) / 1000 # convert to euro/kWh

# -------------------- settings -------------------- #
# pv
pv_battery_max = 15 # battery capacity in kWh
pv_battery_energy_rate = 1 # kWh
# pv_battery_init = 0 # random
pv_battery_eff = 0.95 # efficiency of the battery charging/discharging process

# ev
home_charger = 4 # maximum power of home charger in kW
energy_rate = home_charger / 4 # maximum amout of energy that can be charged in 15 minutes
ev_in = 24 # plug in at 2016-05-01 18:00
ev_out = 88 # plug out at 2016-05-02 10:00

soc_max = 67 # ev battery capacity in kWh taken from the Tesla Model Y
soc_demand = 6 # energy demand of the EV in kWh, the assumption is that the EV is fully charged at the end of the day
soc_init = soc_max - soc_demand
ev_eff = 0.95 # efficiency of the EV charging/discharging process

# price
price_penalty = 0.1 # tuning parameter for the price penalty
power_th = 3 # threshold for peak load in kW

# %% [markdown]
# Benchmark

# %%
cost_benchmark = []
excess_tot = 0 # total excess demand
gimport_tot = 0 # total grid import

for day in range(n_days):
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day
        
    tot_demand = dishwasher_ini + critical_ini + wm_ini + ev_ini
    normal_demand_idx = np.where(tot_demand <= power_th/4)[0] # indices of normal demand
    excess_demand_idx = np.where(tot_demand > power_th/4)[0] # indices of excess demand

    excess_tot += np.sum(tot_demand[excess_demand_idx]) # accumulate the excess demand
    gimport_tot += np.sum(tot_demand) # accumulate the grid import

    cost_per_day = np.dot(tot_demand[normal_demand_idx], price_ini[normal_demand_idx]) + price_penalty * np.sum(tot_demand[excess_demand_idx]) # cost of the benchmark scenarioeuro')cenarioeuro')
    cost_benchmark.append(cost_per_day)

print('Cost benchmark: ', cost_benchmark, 'euro')
print(sum(cost_benchmark), 'euro')
print('Total excess demand: ', excess_tot, 'kWh')
print('Total grid import: ', gimport_tot, 'kWh')
# Out:
# Cost benchmark:  [1.38760886, 1.27182262, 0.8435481, 1.04481746, 2.19296253, 1.46399123, 1.2920679800000001] euro
# 9.496818780000002 euro
# Total excess demand:  67.70700000000001 kWh
# Total grid import:  161.139 kWh

# %% [markdown]
# Scenario 1: unidirectional EV only

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario1 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario1 = []

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 1 #########################
    # Create a Gurobi model
    model1 = gp.Model(f"Scenario 1: uni EV, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        print(f"day {day}, wm_cyc_start:{wm_cyc_start}")
        wm_energy, _ = constrain_nonflex(model1, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model1.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model1, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model1.update()

    # EV related variables
    ev_pos_energy, ev_neg_energy, ev_soc = constrain_flex(model1, soc_init, soc_demand, soc_max, energy_rate, 0, ev_eff, ev_in, ev_out, duration, "ev")
    model1.update()


    tot_demand = [] # add profiles of all cycles together to get the final wm power profile
    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += ev_pos_energy[t] + ev_neg_energy[t] + critical_ini[t]
        model1.addConstr(demand >= 0, name=f"demand_nonneg_{t}") # ensure that the demand is non-negative

        tot_demand.append(demand) 

    # Now deal with the objective function considering the violation of power threshold
    excess = model1.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model1.addConstr(
            excess[t] >= tot_demand[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model1.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model1.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    # cost part 1: cost of the energy consumed 
    # after you’ve set up penalty_flag[t] exactly as before…

    # Build a single “effective price” per t:
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * tot_demand[t]
        for t in range(duration)
    )

    # cost = gp.quicksum(tot_demand[t] * price[t] for t in range(duration))

    model1.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model1.optimize()
    
    
    # Check the optimization status
    if model1.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model1.objVal)

        cost_scenario1.append(model1.objVal)
        
        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario1.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario1.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        ev_pos_opt = get_profile(ev_pos_energy, duration, duration, type='flex')
        ev_neg_opt = get_profile(ev_neg_energy, duration, duration, type='flex')
        data_scenario1.loc[day*duration:(day+1)*duration-1, 'ev'] = np.array(ev_pos_opt) + np.array(ev_neg_opt)
        data_scenario1.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini
    
    else:
        print("No optimal solution found. Status code:", model1.status)
# Out:
# days: 0
# day 0, wm_cyc_start:[79]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 833 columns and 3337 nonzeros
# Model fingerprint: 0xde972a07
# Model has 384 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 545 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [4e-03, 7e+01]
# Presolve removed 514 rows and 638 columns
# Presolve time: 0.01s
# Presolved: 204 rows, 297 columns, 766 nonzeros
# Variable types: 198 continuous, 99 integer (99 binary)
# Found heuristic solution: objective 0.5468968
# Found heuristic solution: objective 0.5460695
#
# Root relaxation: objective 5.392016e-01, 78 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.53920    0    5    0.54607    0.53920  1.26%     -    0s
#      0     0    0.53968    0    5    0.54607    0.53968  1.17%     -    0s
# H    0     0                       0.5441954    0.53968  0.83%     -    0s
#      0     0          -    0         0.54420    0.54418  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 3
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (82 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.544195 0.54607 0.546897
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.441954184211e-01, best bound 5.441771394737e-01, gap 0.0034%
# Optimal solution found.
# Objective value (cost): 0.5441954184210526
# days: 1
# day 1, wm_cyc_start:[1]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 833 columns and 3595 nonzeros
# Model fingerprint: 0xd8f01882
# Model has 384 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 545 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 492 rows and 598 columns
# Presolve time: 0.01s
# Presolved: 233 rows, 344 columns, 1133 nonzeros
# Variable types: 222 continuous, 122 integer (119 binary)
# Found heuristic solution: objective 0.7047125
#
# Root relaxation: objective 6.945130e-01, 97 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.6945130    0.69451  0.00%     -    0s
#
# Explored 1 nodes (97 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.694513 0.704713
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.945130094737e-01, best bound 6.945130094737e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.6945130094736844
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 449 columns and 994 nonzeros
# Model fingerprint: 0x914ab126
# Model has 192 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 353 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 353 rows and 321 columns
# Presolve time: 0.00s
# Presolved: 129 rows, 192 columns, 384 nonzeros
# Variable types: 128 continuous, 64 integer (64 binary)
# Found heuristic solution: objective 0.5437344
#
# Root relaxation: objective 5.436368e-01, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.54364    0    1    0.54373    0.54364  0.02%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.543734
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.437344447368e-01, best bound 5.437344447368e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5437344447368421
# days: 3
# day 3, wm_cyc_start:[84]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 517 rows, 641 columns and 2383 nonzeros
# Model fingerprint: 0x1cfc6ebe
# Model has 288 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 449 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve removed 452 rows and 512 columns
# Presolve time: 0.00s
# Presolved: 133 rows, 197 columns, 400 nonzeros
# Variable types: 128 continuous, 69 integer (69 binary)
# Found heuristic solution: objective 0.5338992
#
# Root relaxation: cutoff, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.53390    0.53390  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.533899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.338991794737e-01, best bound 5.338991794737e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5338991794736843
# days: 4
# day 4, wm_cyc_start:[7, 19, 81, 88]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 916 rows, 1409 columns and 7562 nonzeros
# Model fingerprint: 0x1b925d9a
# Model has 672 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 833 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 8e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [2e-02, 7e+01]
# Presolve removed 775 rows and 1157 columns
# Presolve time: 0.01s
# Presolved: 280 rows, 391 columns, 1480 nonzeros
# Variable types: 273 continuous, 118 integer (118 binary)
# Found heuristic solution: objective 1.1604734
# Found heuristic solution: objective 0.9692495
#
# Root relaxation: objective 9.382686e-01, 150 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.93827    0    3    0.96925    0.93827  3.20%     -    0s
# H    0     0                       0.9476971    0.93827  0.99%     -    0s
#      0     0    0.93910    0    4    0.94770    0.93910  0.91%     -    0s
#      0     0    0.93910    0   28    0.94770    0.93910  0.91%     -    0s
# H    0     0                       0.9438397    0.93910  0.50%     -    0s
# H    0     0                       0.9431217    0.93910  0.43%     -    0s
# H    0     0                       0.9417905    0.93910  0.29%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Implied bound: 5
#   GUB cover: 1
#   Relax-and-lift: 3
#
# Explored 1 nodes (243 simplex iterations) in 0.06 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.941791 0.943122 0.94384 ... 1.16047
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.417905352632e-01, best bound 9.417755284107e-01, gap 0.0016%
# Optimal solution found.
# Objective value (cost): 0.9417905352631581
# days: 5
# day 5, wm_cyc_start:[20, 36, 74]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 717 rows, 1025 columns and 4191 nonzeros
# Model fingerprint: 0x0db73f75
# Model has 480 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 641 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 592 rows and 788 columns
# Presolve time: 0.01s
# Presolved: 250 rows, 362 columns, 1100 nonzeros
# Variable types: 242 continuous, 120 integer (120 binary)
# Found heuristic solution: objective 0.6505543
# Found heuristic solution: objective 0.6448950
#
# Root relaxation: objective 6.423272e-01, 81 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.64233    0    3    0.64489    0.64233  0.40%     -    0s
# *    0     0               0       0.6435442    0.64354  0.00%     -    0s
#
# Explored 1 nodes (86 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.643544 0.644895 0.650554
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.435442447368e-01, best bound 6.435442447368e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.6435442447368422
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 449 columns and 994 nonzeros
# Model fingerprint: 0x3af44cdb
# Model has 192 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 353 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve removed 353 rows and 321 columns
# Presolve time: 0.00s
# Presolved: 129 rows, 192 columns, 384 nonzeros
# Variable types: 128 continuous, 64 integer (64 binary)
# Found heuristic solution: objective 0.5328812
#
# Root relaxation: cutoff, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.53288    0.53288  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.532881
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.328811626316e-01, best bound 5.328811626316e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5328811626315791

# %%
print(sum(cost_scenario1))
data_scenario1.to_csv('output/winter_scenario1.csv')
# Out:
# 4.434557994736843

# %% [markdown]
# Scenario 2: bidirectional EV

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario2 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario2 = []

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 1 #########################
    # Create a Gurobi model
    model2 = gp.Model(f"Scenario 2: bi EV, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        print(f"day {day}, wm_cyc_start:{wm_cyc_start}")
        wm_energy, _ = constrain_nonflex(model2, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model2.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model2, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model2.update()

    # EV related variables
    ev_pos_energy, ev_neg_energy, ev_soc = constrain_flex(model2, soc_init, soc_demand, soc_max, energy_rate, -energy_rate, ev_eff, ev_in, ev_out, duration, "ev")
    model2.update()

    import_demand = [] 
    export_demand = [] 
    g_import = model2.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, name="gimport") # grid import variable
    g_export = model2.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, name="gexport") # grid import variable

    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += ev_pos_energy[t] + ev_neg_energy[t] + critical_ini[t]
        model2.addConstr(g_import[t]-g_export[t] == demand, name=f"demand_balance_{t}") # the grid import minus the grid export should equal the demand
        model2.addConstr(g_import[t]*g_export[t] == 0, name=f"gimport_gexport_{t}") # only one of the two can be non-zero

        import_demand.append(g_import[t]) # append the grid import to the list  
        export_demand.append(g_export[t]) # append the grid export to the list

    # Now deal with the objective function considering the violation of power thresholde function considering the violation of power threshold
    excess = model2.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model2.addConstr(
            excess[t] >= g_import[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model2.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model2.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    # cost part 1: cost of the energy consumed 
    # after you’ve set up penalty_flag[t] exactly as before…

    # Build a single “effective price” per t:
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * g_import[t] - price[t] * g_export[t]
        for t in range(duration)
    )

    # cost = gp.quicksum(tot_demand[t] * price[t] for t in range(duration))

    model2.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model2.optimize()
    
    # Check the optimization status
    if model2.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model2.objVal)

        cost_scenario2.append(model2.objVal)

        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario2.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario2.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        ev_pos_opt = get_profile(ev_pos_energy, duration, duration, type='flex')
        ev_neg_opt = get_profile(ev_neg_energy, duration, duration, type='flex')
        data_scenario2.loc[day*duration:(day+1)*duration-1, 'ev'] = np.array(ev_pos_opt) + np.array(ev_neg_opt)
        data_scenario2.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini

    else:
        print("No optimal solution found. Status code:", model2.status)

    # print(day)
# Out:
# days: 0
# day 0, wm_cyc_start:[79]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 1025 columns and 3241 nonzeros
# Model fingerprint: 0xb3553f03
# Model has 96 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 737 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [4e-03, 7e+01]
# Presolve removed 131 rows and 443 columns
# Presolve time: 0.01s
# Presolved: 553 rows, 650 columns, 1712 nonzeros
# Presolved model has 4 SOS constraint(s)
# Variable types: 386 continuous, 264 integer (226 binary)
# Found heuristic solution: objective 0.5460695
#
# Root relaxation: objective 3.884812e-01, 433 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.38848    0   33    0.54607    0.38848  28.9%     -    0s
# H    0     0                       0.4364372    0.38848  11.0%     -    0s
# *    0     0               0       0.4362363    0.43624  0.00%     -    0s
#
# Cutting planes:
#   MIR: 78
#   Flow cover: 12
#   Relax-and-lift: 32
#
# Explored 1 nodes (539 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.436236 0.436437 0.54607
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.362362542500e-01, best bound 4.362362542500e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.4362362542500015
# days: 1
# day 1, wm_cyc_start:[1]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 1025 columns and 3499 nonzeros
# Model fingerprint: 0xb9b0c3b9
# Model has 96 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 737 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 111 rows and 406 columns
# Presolve time: 0.01s
# Presolved: 574 rows, 688 columns, 2041 nonzeros
# Presolved model has 3 SOS constraint(s)
# Variable types: 386 continuous, 302 integer (245 binary)
# Found heuristic solution: objective 0.7100224
#
# Root relaxation: objective 5.413517e-01, 462 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.54135    0   33    0.71002    0.54135  23.8%     -    0s
# H    0     0                       0.5862288    0.54135  7.66%     -    0s
# *    0     0               0       0.5857553    0.58576  0.00%     -    0s
#
# Cutting planes:
#   MIR: 79
#   Flow cover: 11
#   Relax-and-lift: 33
#
# Explored 1 nodes (561 simplex iterations) in 0.06 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.585755 0.586229 0.710022
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.857552933500e-01, best bound 5.857552933500e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5857552933500008
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 641 columns and 1090 nonzeros
# Model fingerprint: 0xb4c3cacc
# Model has 96 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 545 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve added 18 rows and 0 columns
# Presolve removed 0 rows and 142 columns
# Presolve time: 0.00s
# Presolved: 500 rows, 563 columns, 1378 nonzeros
# Variable types: 373 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 0.5437344
#
# Root relaxation: objective 4.042714e-01, 314 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.40427    0   35    0.54373    0.40427  25.6%     -    0s
# H    0     0                       0.4412040    0.40427  8.37%     -    0s
# H    0     0                       0.4261592    0.40427  5.14%     -    0s
# H    0     0                       0.4260541    0.42603  0.01%     -    0s
#      0     0    0.42605    0    2    0.42605    0.42605  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 42
#   Flow cover: 48
#   Relax-and-lift: 18
#
# Explored 1 nodes (396 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.426054 0.426159 0.441204 0.543734
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.260540680000e-01, best bound 4.260540680000e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.42605406800000045
# days: 3
# day 3, wm_cyc_start:[84]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 517 rows, 833 columns and 2383 nonzeros
# Model fingerprint: 0x0cb7ea58
# Model has 96 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 641 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve removed 80 rows and 332 columns
# Presolve time: 0.01s
# Presolved: 501 rows, 565 columns, 1384 nonzeros
# Variable types: 374 continuous, 191 integer (191 binary)
# Found heuristic solution: objective 0.5338992
#
# Root relaxation: objective 3.971052e-01, 317 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.39711    0   35    0.53390    0.39711  25.6%     -    0s
# H    0     0                       0.4209818    0.39711  5.67%     -    0s
# H    0     0                       0.4207435    0.42070  0.01%     -    0s
#      0     0    0.42074    0    1    0.42074    0.42074  0.00%     -    0s
#
# Cutting planes:
#   MIR: 49
#   Flow cover: 55
#   Relax-and-lift: 17
#
# Explored 1 nodes (397 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.420743 0.420982 0.533899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.207434828000e-01, best bound 4.207434828000e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.4207434828000014
# days: 4
# day 4, wm_cyc_start:[7, 19, 81, 88]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 916 rows, 1601 columns and 7178 nonzeros
# Model fingerprint: 0x26d4e0d4
# Model has 96 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 1025 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [4e-02, 7e+01]
# Presolve removed 399 rows and 973 columns
# Presolve time: 0.01s
# Presolved: 583 rows, 694 columns, 2259 nonzeros
# Variable types: 378 continuous, 316 integer (243 binary)
# Found heuristic solution: objective 1.2652411
# Found heuristic solution: objective 0.9755466
# Found heuristic solution: objective 0.8640056
#
# Root relaxation: objective 7.007324e-01, 446 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.70073    0   58    0.86401    0.70073  18.9%     -    0s
# H    0     0                       0.7794065    0.70073  10.1%     -    0s
#      0     0    0.77750    0   14    0.77941    0.77750  0.24%     -    0s
# H    0     0                       0.7781948    0.77750  0.09%     -    0s
# H    0     0                       0.7780015    0.77750  0.06%     -    0s
# H    0     0                       0.7776480    0.77750  0.02%     -    0s
#      0     0    0.77750    0    7    0.77765    0.77750  0.02%     -    0s
#      0     0    0.77750    0    7    0.77765    0.77750  0.02%     -    0s
# H    0     0                       0.7775510    0.77750  0.01%     -    0s
#
# Explored 1 nodes (660 simplex iterations) in 0.10 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.777551 0.777648 0.777648 ... 1.26524
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.775509640443e-01, best bound 7.775032980055e-01, gap 0.0061%
# Optimal solution found.
# Objective value (cost): 0.7775509640443199
# days: 5
# day 5, wm_cyc_start:[20, 36, 74]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 717 rows, 1217 columns and 3999 nonzeros
# Model fingerprint: 0xd37aea19
# Model has 96 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 833 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 220 rows and 608 columns
# Presolve time: 0.01s
# Presolved: 561 rows, 673 columns, 1910 nonzeros
# Variable types: 374 continuous, 299 integer (242 binary)
# Found heuristic solution: objective 0.6447588
# Found heuristic solution: objective 0.6294684
#
# Root relaxation: objective 4.870559e-01, 458 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.48706    0   33    0.62947    0.48706  22.6%     -    0s
# H    0     0                       0.5261703    0.48706  7.43%     -    0s
#      0     0    0.52555    0    2    0.52617    0.52555  0.12%     -    0s
#      0     0    0.52555    0    7    0.52617    0.52555  0.12%     -    0s
#      0     0    0.52555    0    7    0.52617    0.52555  0.12%     -    0s
# H    0     0                       0.5259120    0.52555  0.07%     -    0s
# H    0     0                       0.5255468    0.52555  0.00%     -    0s
#      0     0    0.52555    0    7    0.52555    0.52555  0.00%     -    0s
#
# Explored 1 nodes (776 simplex iterations) in 0.08 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.525547 0.525912 0.52617 ... 0.644759
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.255467812000e-01, best bound 5.255467812000e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5255467812000005
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 641 columns and 1090 nonzeros
# Model fingerprint: 0xf93281d5
# Model has 96 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 545 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve added 18 rows and 0 columns
# Presolve removed 0 rows and 142 columns
# Presolve time: 0.00s
# Presolved: 500 rows, 563 columns, 1378 nonzeros
# Variable types: 373 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 0.5328812
#
# Root relaxation: objective 3.916795e-01, 315 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.39168    0   34    0.53288    0.39168  26.5%     -    0s
# H    0     0                       0.4115008    0.39168  4.82%     -    0s
#      0     0          -    0         0.41150    0.41148  0.01%     -    0s
#
# Cutting planes:
#   MIR: 42
#   Flow cover: 48
#   Relax-and-lift: 18
#
# Explored 1 nodes (390 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.411501 0.532881
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.115008213000e-01, best bound 4.114753018652e-01, gap 0.0062%
# Optimal solution found.
# Objective value (cost): 0.41150082130000076

# %%
print(sum(cost_scenario2))
data_scenario2.to_csv('output/winter_scenario2.csv', index=False)
# Out:
# 3.583387664944325

# %% [markdown]
# Scenario 3: PV + Battery, Dummy EV

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario3 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario3 = []

pv_battery_init = 0 # initial state of charge of the battery. It changes every day, so we need to reset it for each day

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 3 #########################
    # Create a Gurobi model
    model3 = gp.Model(f"Scenario 3: PV+BESS, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        wm_energy, _ = constrain_nonflex(model3, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model3.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model3, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model3.update()

    # PV and BESS related variables
    battery_pos_energy, battery_neg_energy, battery_soc = constrain_pv(model3, pv_battery_init, pv_battery_max, pv_battery_energy_rate, pv_battery_eff, duration, 'pv')
    model3.update()

    import_demand = [] 
    export_demand = [] 
    g_import = model3.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, name="gimport") # grid import variable
    g_export = model3.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, name="gexport") # grid import variable

    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += critical_ini[t] + ev_ini[t]
        demand += battery_pos_energy[t] + battery_neg_energy[t] - pv_ini[t] # the energy demand is the sum of the washing machine, dishwasher, critical appliances, EV and the battery
        # model3.addConstr(demand >= 0, name=f"demand_nonneg_{t}") # ensure that the demand is non-negative
        model3.addConstr(g_import[t]-g_export[t] == demand, name=f"demand_balance_{t}") # the grid import minus the grid export should equal the demand
        model3.addConstr(g_import[t]*g_export[t] == 0, name=f"gimport_gexport_{t}") # only one of the two can be non-zero

        import_demand.append(g_import[t]) # append the grid import to the list  
        export_demand.append(g_export[t]) # append the grid export to the list


    # Now deal with the objective function considering the violation of power threshold
    excess = model3.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model3.addConstr(
            excess[t] >= g_import[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model3.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model3.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * g_import[t] - price[t] * g_export[t]
        for t in range(duration)
    )
    model3.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model3.optimize()

    # reset the initial state of charge of the battery for the next day
    pv_battery_init = battery_soc[duration].X  # update the initial state of charge of the battery for the next day

    # Check the optimization status
    if model3.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model3.objVal)
        cost_scenario3.append(model3.objVal)

        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario3.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario3.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        bess_pos_opt = get_profile(battery_pos_energy, duration, duration, type='flex')
        bess_neg_opt = get_profile(battery_neg_energy, duration, duration, type='flex')
        data_scenario3.loc[day*duration:(day+1)*duration-1, 'pv_bess'] = np.array(bess_pos_opt) + np.array(bess_neg_opt)
        data_scenario3.loc[day*duration:(day+1)*duration-1, 'ev'] = ev_ini
        data_scenario3.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini

    else:
        print("No optimal solution found. Status code:", model3.status)
# Out:
# days: 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 583 rows, 1057 columns and 3304 nonzeros
# Model fingerprint: 0x9c8659c3
# Model has 96 quadratic objective terms
# Model has 192 quadratic constraints
# Variable types: 769 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [9e-03, 1e+00]
# Presolve added 117 rows and 0 columns
# Presolve removed 0 rows and 231 columns
# Presolve time: 0.01s
# Presolved: 796 rows, 922 columns, 2378 nonzeros
# Variable types: 567 continuous, 355 integer (313 binary)
# Found heuristic solution: objective 0.5897107
# Found heuristic solution: objective 0.4489190
#
# Root relaxation: objective 9.246421e-02, 574 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.09246    0   45    0.44892    0.09246  79.4%     -    0s
# H    0     0                       0.1332697    0.09246  30.6%     -    0s
#      0     0    0.13222    0    2    0.13327    0.13222  0.79%     -    0s
#      0     0    0.13222    0    9    0.13327    0.13222  0.79%     -    0s
# H    0     0                       0.1323377    0.13222  0.09%     -    0s
# H    0     0                       0.1322215    0.13222  0.00%     -    0s
#      0     0    0.13222    0    9    0.13222    0.13222  0.00%     -    0s
#
# Explored 1 nodes (962 simplex iterations) in 0.08 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.132221 0.132338 0.13327 ... 0.589711
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.322214812541e-01, best bound 1.322214812541e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.13222148125408242
# days: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 583 rows, 1057 columns and 3562 nonzeros
# Model fingerprint: 0x302c5d50
# Model has 96 quadratic objective terms
# Model has 192 quadratic constraints
# Variable types: 769 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [2e-03, 1e+00]
# Presolve added 140 rows and 0 columns
# Presolve removed 0 rows and 190 columns
# Presolve time: 0.01s
# Presolved: 819 rows, 963 columns, 2698 nonzeros
# Variable types: 569 continuous, 394 integer (332 binary)
# Found heuristic solution: objective 0.6772518
# Found heuristic solution: objective 0.6010565
#
# Root relaxation: objective 2.013894e-01, 646 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.20139    0   61    0.60106    0.20139  66.5%     -    0s
# H    0     0                       0.3102160    0.20139  35.1%     -    0s
#      0     0    0.30550    0    3    0.31022    0.30550  1.52%     -    0s
# H    0     0                       0.3055017    0.30550  0.00%     -    0s
#      0     0    0.30550    0    2    0.30550    0.30550  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#   Implied bound: 3
#   Clique: 1
#   MIR: 32
#   Flow cover: 76
#   Relax-and-lift: 16
#   PSD: 2
#
# Explored 1 nodes (833 simplex iterations) in 0.06 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.305502 0.310216 0.601057 0.677252
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.055017137000e-01, best bound 3.055017137000e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.30550171369999934
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 385 rows, 673 columns and 1153 nonzeros
# Model fingerprint: 0x777f42a4
# Model has 96 quadratic objective terms
# Model has 192 quadratic constraints
# Variable types: 577 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e-02, 2e+00]
# Presolve added 274 rows and 82 columns
# Presolve time: 0.01s
# Presolved: 755 rows, 851 columns, 2073 nonzeros
# Variable types: 569 continuous, 282 integer (282 binary)
# Found heuristic solution: objective 0.4272439
#
# Root relaxation: objective 1.812135e-02, 268 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.01812    0   47    0.42724    0.01812  95.8%     -    0s
# H    0     0                       0.0514195    0.01812  64.8%     -    0s
# *    0     0               0       0.0513835    0.05138  0.00%     -    0s
#
# Cutting planes:
#   Flow cover: 8
#   Relax-and-lift: 14
#   PSD: 6
#
# Explored 1 nodes (375 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.0513835 0.0514195 0.427244
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.138345764079e-02, best bound 5.138345764079e-02, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.051383457640789096
# days: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 484 rows, 865 columns and 2446 nonzeros
# Model fingerprint: 0x8859d70f
# Model has 96 quadratic objective terms
# Model has 192 quadratic constraints
# Variable types: 673 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [4e-03, 1e+00]
# Presolve added 175 rows and 0 columns
# Presolve removed 0 rows and 109 columns
# Presolve time: 0.00s
# Presolved: 755 rows, 852 columns, 2081 nonzeros
# Variable types: 569 continuous, 283 integer (283 binary)
# Found heuristic solution: objective 0.3969954
#
# Root relaxation: objective 1.376299e-02, 279 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.01376    0   46    0.39700    0.01376  96.5%     -    0s
# H    0     0                       0.0583338    0.01376  76.4%     -    0s
# *    0     0               0       0.0567032    0.05670  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 2
#   MIR: 17
#   Flow cover: 61
#   RLT: 1
#   Relax-and-lift: 45
#   PSD: 13
#
# Explored 1 nodes (402 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.0567032 0.0583338 0.396995
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.670323365526e-02, best bound 5.670323365526e-02, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.05670323365526312
# days: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 883 rows, 1633 columns and 7241 nonzeros
# Model fingerprint: 0x2b8dc1c5
# Model has 96 quadratic objective terms
# Model has 192 quadratic constraints
# Variable types: 1057 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e-03, 2e+01]
# Presolve removed 147 rows and 750 columns
# Presolve time: 0.02s
# Presolved: 831 rows, 978 columns, 2922 nonzeros
# Variable types: 567 continuous, 411 integer (336 binary)
# Found heuristic solution: objective 1.3507545
# Found heuristic solution: objective 0.8834739
#
# Root relaxation: objective 5.084565e-01, 578 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.50846    0   48    0.88347    0.50846  42.4%     -    0s
# H    0     0                       0.5952715    0.50846  14.6%     -    0s
#      0     0    0.59284    0   10    0.59527    0.59284  0.41%     -    0s
#      0     0    0.59285    0    7    0.59527    0.59285  0.41%     -    0s
# H    0     0                       0.5928957    0.59285  0.01%     -    0s
#
# Explored 1 nodes (1018 simplex iterations) in 0.07 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.592896 0.595272 0.595272 ... 1.35075
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.928957188040e-01, best bound 5.928506504040e-01, gap 0.0076%
# Optimal solution found.
# Objective value (cost): 0.5928957188040155
# days: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 684 rows, 1249 columns and 4062 nonzeros
# Model fingerprint: 0xf5c989be
# Model has 96 quadratic objective terms
# Model has 192 quadratic constraints
# Variable types: 865 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e-02, 1e+01]
# Presolve added 45 rows and 0 columns
# Presolve removed 0 rows and 370 columns
# Presolve time: 0.01s
# Presolved: 825 rows, 975 columns, 2659 nonzeros
# Variable types: 569 continuous, 406 integer (339 binary)
# Found heuristic solution: objective 0.5740405
#
# Root relaxation: objective 2.224815e-01, 586 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.22248    0   48    0.57404    0.22248  61.2%     -    0s
# H    0     0                       0.3076258    0.22248  27.7%     -    0s
#      0     0    0.30735    0    3    0.30763    0.30735  0.09%     -    0s
#      0     0    0.30735    0    3    0.30763    0.30735  0.09%     -    0s
# H    0     0                       0.3073799    0.30735  0.01%     -    0s
# H    0     0                       0.3073481    0.30735  0.00%     -    0s
#      0     0    0.30735    0    3    0.30735    0.30735  0.00%     -    0s
#
# Cutting planes:
#   Cover: 3
#   Implied bound: 2
#   MIR: 43
#   Flow cover: 74
#   RLT: 1
#   Relax-and-lift: 37
#   PSD: 1
#
# Explored 1 nodes (745 simplex iterations) in 0.08 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.307348 0.30738 0.307626 0.574041
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.073480582750e-01, best bound 3.073480582750e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.30734805827499967
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 385 rows, 673 columns and 1153 nonzeros
# Model fingerprint: 0xfadf6f2c
# Model has 96 quadratic objective terms
# Model has 192 quadratic constraints
# Variable types: 577 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e-02, 1e+00]
# Presolve added 274 rows and 82 columns
# Presolve time: 0.01s
# Presolved: 755 rows, 851 columns, 2073 nonzeros
# Variable types: 569 continuous, 282 integer (282 binary)
# Found heuristic solution: objective 0.4234342
#
# Root relaxation: objective 5.069177e-02, 273 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.05069    0   46    0.42343    0.05069  88.0%     -    0s
# H    0     0                       0.1025727    0.05069  50.6%     -    0s
# H    0     0                       0.1020193    0.10188  0.14%     -    0s
#      0     0    0.10202    0    5    0.10202    0.10202  0.00%     -    0s
#
# Cutting planes:
#   Cover: 1
#   Implied bound: 3
#   MIR: 16
#   Flow cover: 63
#   RLT: 2
#   Relax-and-lift: 42
#   PSD: 7
#
# Explored 1 nodes (391 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.102019 0.102573 0.423434
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.020193205500e-01, best bound 1.020193205500e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.10201932055000004

# %%
print(sum(cost_scenario3))
data_scenario3.to_csv('output/winter_scenario3.csv', index=False)
# Out:
# 1.548072983879149

# %% [markdown]
# Benchmark: w/o PV, w/o demand response
# meaning EV is charged using the dumb charging strategy. The penalty works in the following way: if the total load exceeds the threshold, the price will become the product of the maximum price and a tuning parameter.

# %% [markdown]
# Scenario 4: All together

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario4 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario4 = []

pv_battery_init = 0 # initial state of charge of the battery. It changes every day, so we need to reset it for each day

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 4 #########################
    # Create a Gurobi model
    model4 = gp.Model(f"Scenario 4: All together, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        wm_energy, _ = constrain_nonflex(model4, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model4.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model4, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model4.update()

    # EV related variables
    ev_pos_energy, ev_neg_energy, _ = constrain_flex(model4, soc_init, soc_demand, soc_max, energy_rate, -energy_rate, ev_eff, ev_in, ev_out, duration, "ev")
    model4.update()

    # PV and BESS related variables
    battery_pos_energy, battery_neg_energy, battery_soc = constrain_pv(model4, pv_battery_init, pv_battery_max, pv_battery_energy_rate, pv_battery_eff, duration, 'pv')
    model4.update()

    import_demand = [] 
    export_demand = [] 
    g_import = model4.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, name="gimport") # grid import variable
    g_export = model4.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, name="gexport") # grid import variable

    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += ev_pos_energy[t] + ev_neg_energy[t] + critical_ini[t]
        demand += battery_pos_energy[t] + battery_neg_energy[t] - pv_ini[t] # the energy demand is the sum of the washing machine, dishwasher, critical appliances, EV and the battery
        
        model4.addConstr(g_import[t]-g_export[t] == demand, name=f"demand_balance_{t}") # the grid import minus the grid export should equal the demand
        model4.addConstr(g_import[t]*g_export[t] == 0, name=f"gimport_gexport_{t}") # only one of the two can be non-zero

        import_demand.append(g_import[t]) # append the grid import to the list  
        export_demand.append(g_export[t]) # append the grid export to the list 

    # Now deal with the objective function considering the violation of power threshold
    excess = model4.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model4.addConstr(
            excess[t] >= g_import[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model4.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model4.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * g_import[t] - price[t] * g_export[t]
        for t in range(duration)
    )
    model4.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model4.optimize()

    pv_battery_init = battery_soc[duration].X  # update the initial state of charge of the battery for the next day

    # Check the optimization status
    if model4.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model4.objVal)
        cost_scenario4.append(model4.objVal)

        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario4.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario4.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        bess_pos_opt = get_profile(battery_pos_energy, duration, duration, type='flex')
        bess_neg_opt = get_profile(battery_neg_energy, duration, duration, type='flex')
        data_scenario4.loc[day*duration:(day+1)*duration-1, 'pv_bess'] = np.array(bess_pos_opt) + np.array(bess_neg_opt)

        ev_pos_opt = get_profile(ev_pos_energy, duration, duration, type='flex')
        ev_neg_opt = get_profile(ev_neg_energy, duration, duration, type='flex')
        data_scenario4.loc[day*duration:(day+1)*duration-1, 'ev'] = np.array(ev_pos_opt) + np.array(ev_neg_opt)
        data_scenario4.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini

    else:
        print("No optimal solution found. Status code:", model4.status)
# Out:
# days: 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 713 rows, 1314 columns and 3818 nonzeros
# Model fingerprint: 0xb32c2ba7
# Model has 96 quadratic objective terms
# Model has 256 quadratic constraints
# Variable types: 1026 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [9e-03, 7e+01]
# Presolve added 182 rows and 0 columns
# Presolve removed 0 rows and 230 columns
# Presolve time: 0.01s
# Presolved: 991 rows, 1180 columns, 3032 nonzeros
# Variable types: 756 continuous, 424 integer (382 binary)
# Found heuristic solution: objective 0.6533018
# Found heuristic solution: objective 0.5275063
# Found heuristic solution: objective 0.5228164
#
# Root relaxation: objective -1.442301e-01, 621 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.14423    0   53    0.52282   -0.14423   128%     -    0s
# H    0     0                       0.0233451   -0.14423   718%     -    0s
#      0     0    0.02077    0   12    0.02335    0.02077  11.0%     -    0s
#      0     0    0.02077    0   12    0.02335    0.02077  11.0%     -    0s
# H    0     0                       0.0214542    0.02077  3.17%     -    0s
# H    0     0                       0.0213939    0.02077  2.89%     -    0s
# H    0     0                       0.0207827    0.02077  0.04%     -    0s
# H    0     0                       0.0207749    0.02077  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 2
#   MIR: 33
#   Flow cover: 123
#   Relax-and-lift: 15
#
# Explored 1 nodes (861 simplex iterations) in 0.10 seconds (0.04 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: 0.0207749 0.0207827 0.0213939 ... 0.653302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.077492990526e-02, best bound 2.077492990526e-02, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.020774929905264444
# days: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 713 rows, 1314 columns and 4076 nonzeros
# Model fingerprint: 0x8c1bee5a
# Model has 96 quadratic objective terms
# Model has 256 quadratic constraints
# Variable types: 1026 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [2e-03, 7e+01]
# Presolve added 205 rows and 0 columns
# Presolve removed 0 rows and 189 columns
# Presolve time: 0.01s
# Presolved: 1014 rows, 1221 columns, 3351 nonzeros
# Variable types: 758 continuous, 463 integer (401 binary)
# Found heuristic solution: objective 0.7464381
# Found heuristic solution: objective 0.6840048
# Found heuristic solution: objective 0.6626170
# Found heuristic solution: objective 0.6528978
#
# Root relaxation: objective -3.219604e-02, 768 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.03220    0   77    0.65290   -0.03220   105%     -    0s
# H    0     0                       0.2010838   -0.03220   116%     -    0s
# H    0     0                       0.1948474    0.18988  2.55%     -    0s
#      0     0    0.19402    0   13    0.19485    0.19402  0.43%     -    0s
#      0     0    0.19402    0   13    0.19485    0.19402  0.43%     -    0s
# H    0     0                       0.1940154    0.19402  0.00%     -    0s
#
# Cutting planes:
#   MIR: 34
#   Flow cover: 123
#   RLT: 3
#   Relax-and-lift: 14
#
# Explored 1 nodes (1128 simplex iterations) in 0.10 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 0.194015 0.194847 0.201084 ... 0.746438
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.940153511500e-01, best bound 1.940153511500e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.1940153511500003
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 515 rows, 930 columns and 1667 nonzeros
# Model fingerprint: 0xa97a4168
# Model has 96 quadratic objective terms
# Model has 256 quadratic constraints
# Variable types: 834 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [1e-02, 7e+01]
# Presolve added 339 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 950 rows, 1109 columns, 2727 nonzeros
# Variable types: 758 continuous, 351 integer (351 binary)
# Found heuristic solution: objective 0.5044987
#
# Root relaxation: objective -1.936942e-01, 477 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.19369    0   53    0.50450   -0.19369   138%     -    0s
# H    0     0                      -0.0658222   -0.19369   194%     -    0s
#      0     0   -0.06613    0   10   -0.06582   -0.06613  0.47%     -    0s
# H    0     0                      -0.0661344   -0.06613  0.00%     -    0s
#      0     0   -0.06613    0   10   -0.06613   -0.06613  0.00%     -    0s
#
# Cutting planes:
#   MIR: 49
#   Flow cover: 117
#   Relax-and-lift: 17
#
# Explored 1 nodes (705 simplex iterations) in 0.06 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: -0.0661344 -0.0658222 0.504499
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.613440598421e-02, best bound -6.613440598421e-02, gap 0.0000%
# Optimal solution found.
# Objective value (cost): -0.06613440598420953
# days: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 614 rows, 1122 columns and 2960 nonzeros
# Model fingerprint: 0x736323d4
# Model has 96 quadratic objective terms
# Model has 256 quadratic constraints
# Variable types: 930 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [4e-03, 7e+01]
# Presolve added 240 rows and 0 columns
# Presolve removed 0 rows and 108 columns
# Presolve time: 0.01s
# Presolved: 950 rows, 1110 columns, 2735 nonzeros
# Variable types: 758 continuous, 352 integer (352 binary)
# Found heuristic solution: objective 0.4801451
#
# Root relaxation: objective -1.932505e-01, 505 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.19325    0   53    0.48015   -0.19325   140%     -    0s
# H    0     0                      -0.0480771   -0.19325   302%     -    0s
#      0     0   -0.05079    0   10   -0.04808   -0.05079  5.64%     -    0s
# H    0     0                      -0.0507868   -0.05079  0.00%     -    0s
#      0     0   -0.05079    0   10   -0.05079   -0.05079  0.00%     -    0s
#
# Cutting planes:
#   MIR: 39
#   Flow cover: 114
#   Relax-and-lift: 10
#
# Explored 1 nodes (719 simplex iterations) in 0.07 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: -0.0507868 -0.0480771 0.480145
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.078679984474e-02, best bound -5.078679984474e-02, gap 0.0000%
# Optimal solution found.
# Objective value (cost): -0.050786799844735525
# days: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1013 rows, 1890 columns and 7755 nonzeros
# Model fingerprint: 0x1e7a7279
# Model has 96 quadratic objective terms
# Model has 256 quadratic constraints
# Variable types: 1314 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [6e-03, 7e+01]
# Presolve removed 79 rows and 746 columns
# Presolve time: 0.02s
# Presolved: 1030 rows, 1240 columns, 3573 nonzeros
# Variable types: 758 continuous, 482 integer (406 binary)
# Found heuristic solution: objective 0.9365543
# Found heuristic solution: objective 0.6887648
#
# Root relaxation: objective 1.705856e-01, 676 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.17059    0   56    0.68876    0.17059  75.2%     -    0s
# H    0     0                       0.4189261    0.17059  59.3%     -    0s
#      0     0    0.41430    0   20    0.41893    0.41430  1.10%     -    0s
#      0     0    0.41457    0   20    0.41893    0.41457  1.04%     -    0s
#      0     0    0.41457    0   19    0.41893    0.41457  1.04%     -    0s
# H    0     0                       0.4161385    0.41457  0.38%     -    0s
# H    0     0                       0.4147165    0.41457  0.03%     -    0s
#      0     0    0.41457    0    7    0.41472    0.41457  0.03%     -    0s
#      0     0    0.41459    0    8    0.41472    0.41459  0.03%     -    0s
# H    0     0                       0.4147102    0.41459  0.03%     -    0s
#      0     0    0.41459    0    8    0.41471    0.41459  0.03%     -    0s
# H    0     0                       0.4146201    0.41459  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Lift-and-project: 1
#   Cover: 3
#
# Explored 1 nodes (1355 simplex iterations) in 0.14 seconds (0.07 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: 0.41462 0.41471 0.414717 ... 0.936554
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.146200645104e-01, best bound 4.145863112814e-01, gap 0.0081%
# Optimal solution found.
# Objective value (cost): 0.41462006451038663
# days: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 814 rows, 1506 columns and 4576 nonzeros
# Model fingerprint: 0x15816728
# Model has 96 quadratic objective terms
# Model has 256 quadratic constraints
# Variable types: 1122 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [1e-02, 7e+01]
# Presolve added 110 rows and 0 columns
# Presolve removed 0 rows and 369 columns
# Presolve time: 0.01s
# Presolved: 1020 rows, 1233 columns, 3313 nonzeros
# Variable types: 758 continuous, 475 integer (408 binary)
# Found heuristic solution: objective 0.6192039
# Found heuristic solution: objective 0.6041924
#
# Root relaxation: objective -1.241760e-03, 695 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.00124    0   56    0.60419   -0.00124   100%     -    0s
# H    0     0                       0.1959881   -0.00124   101%     -    0s
#      0     0    0.19432    0   13    0.19599    0.19432  0.85%     -    0s
#      0     0    0.19432    0   13    0.19599    0.19432  0.85%     -    0s
# H    0     0                       0.1954899    0.19432  0.60%     -    0s
# H    0     0                       0.1949018    0.19432  0.30%     -    0s
# H    0     0                       0.1943152    0.19432  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 3
#   MIR: 25
#   Flow cover: 120
#   Relax-and-lift: 10
#
# Explored 1 nodes (936 simplex iterations) in 0.10 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.194315 0.194902 0.19549 ... 0.619204
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.943151766500e-01, best bound 1.943151766500e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.19431517665000153
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 515 rows, 930 columns and 1667 nonzeros
# Model fingerprint: 0xa4ec6c7a
# Model has 96 quadratic objective terms
# Model has 256 quadratic constraints
# Variable types: 834 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [1e-02, 7e+01]
# Presolve added 339 rows and 83 columns
# Presolve time: 0.01s
# Presolved: 950 rows, 1109 columns, 2727 nonzeros
# Variable types: 758 continuous, 351 integer (351 binary)
# Found heuristic solution: objective 0.4899839
#
# Root relaxation: objective -1.606211e-01, 520 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.16062    0   54    0.48998   -0.16062   133%     -    0s
# H    0     0                      -0.0114094   -0.16062  1308%     -    0s
#      0     0   -0.01360    0   10   -0.01141   -0.01360  19.2%     -    0s
# H    0     0                      -0.0136013   -0.01360  0.00%     -    0s
#      0     0   -0.01360    0   10   -0.01360   -0.01360  0.00%     -    0s
#
# Cutting planes:
#   MIR: 34
#   Flow cover: 121
#   Relax-and-lift: 6
#
# Explored 1 nodes (745 simplex iterations) in 0.06 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: -0.0136013 -0.0114094 0.489984
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.360131375000e-02, best bound -1.360131375000e-02, gap 0.0000%
# Optimal solution found.
# Objective value (cost): -0.013601313749998623

# %%
print(sum(cost_scenario4))
data_scenario4.to_csv('output/winter_scenario4.csv', index=False)
# Out:
# 0.6932030026367092
