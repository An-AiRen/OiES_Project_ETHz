# %% [markdown]
# Implement the demand response

# %%
import pandas as pd
import numpy as np
import gurobipy as gp
import matplotlib.pyplot as plt

# %% [markdown]
# Function collection

# %%
def extract_cyc(profile) -> tuple:
    """
    Extract the operation cycles from the profile.
    Returns the start times and profile of the cycles.
    """
    cycles = [] # list of operation cycles
    cycle = [] # current operation cycle
    for i in range(len(profile)):
        if profile[i] > 0:
            cycle.append(i)
        else: # if the profile is 0, it means the cycle is over
            if cycle:
                cycles.append(cycle)
                cycle = []
    if cycle:
        cycles.append(cycle)
        
    return [c[0] for c in cycles], [profile[c] for c in cycles]

def constrain_nonflex(model, cycle_start, cycle_profile, duration, tolerance, name: str):
    """
    Build the optimization constraints for the non-flexible appliances.
    """
    # Create variables
    num_cycle = len(cycle_start)

    app_energy = model.addVars(num_cycle, duration, vtype=gp.GRB.CONTINUOUS, lb=0, name=name+"_power")
    app_start = model.addVars(num_cycle, duration, vtype=gp.GRB.BINARY, name=name+"_start")

    for i, start in enumerate(cycle_start):
        len_cycle = len(cycle_profile[i])
        # constraint (1)&(2): The starting time of each operation should not deviate from the consumer preference
        # time by more than a certain time tolerance. I think it doesn't make any sense to bring the operation ahead
        # of the preference time, so we only consider the delay.
        model.addConstr(gp.quicksum(app_start[i, j] for j in range(start, start + tolerance[i] + 1)) == 1, name=name+f"_start_constr_{i}")

        # constraint: all the operations should complete before the end of the day
        model.addConstr(gp.quicksum(app_start[i, j] for j in range(start, duration-len_cycle+1)) == 1, name=name+f"end_constr_{i}")

        # constraint: every operation should only start once
        model.addConstr(gp.quicksum(app_start[i, j] for j in range(duration)) == 1, name=name+f"_unique_constr_{i}")

        # constraint (3): the operation should not start before the end of the previous operation
        if i > 0:
            model.addConstr(gp.quicksum((app_start[i, j]-app_start[i-1, j])*j for j in range(start, start + tolerance[i] + 1)) >= len_cycle, name=name+f"_overlap_constr_{i}")
        # constraint (4): the shifted operation is calculated as the convolution of the profile and the decision variable
        for j in range(duration):
            conv = gp.quicksum(app_start[i, j-k] * cycle_profile[i][k] for k in range(len_cycle) if j-k >= 0)
            model.addConstr(app_energy[i, j] == conv, name=f"wm_power_constr_{i}_{j}")

    return app_energy, app_start

def constrain_flex(model, soc_init, soc_demand, soc_max, pos_rate, neg_rate, eff, t_in, t_out, duration, name: str):
    """
    Build the optimization constraints for the flexible appliances.
    """
    # constraint (6): the power rate is limited by the maximum charging and discharging power rate
    app_pos_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, ub=pos_rate, name=name+"_pos_power")
    app_neg_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=neg_rate, ub=0, name=name+"_neg_power")

    # assume the lower bound of soc is internally higher than 0 
    app_soc = model.addVars(t_out-t_in+1, vtype=gp.GRB.CONTINUOUS, lb=0, ub=soc_max, name=name+"_soc")

    # constraint (5): the energy demand has to be satisfied within the time window [plug_in, plug_out]
    model.addConstr(app_soc[t_out-t_in] - soc_init == soc_demand, name=name+"_demand_constr")
    # constraint: the initial state of charge is set to the initial value
    model.addConstr(app_soc[0] == soc_init, name=name+f"_soc_init_constr")

    for t in range(duration):
        if t < t_in or t >= t_out:
            # constraint (7): the power rate is limited to 0 outside the time window [plug_in, plug_out]
            model.addConstr(app_pos_energy[t] == 0, name=name+f"_pos_power_constr_{t}")
            model.addConstr(app_neg_energy[t] == 0, name=name+f"_neg_power_constr_{t}")
        
        # transition function of the state of charge
        else:
            model.addConstr(app_soc[t-t_in+1] == app_soc[t-t_in] + app_pos_energy[t]*eff + app_neg_energy[t]/eff, name=name+f"_soc_pos_constr_{t}") 
            model.addConstr(app_pos_energy[t] * app_neg_energy[t] == 0, name=name+f"_pos_neg_constr_{t}") # only one of the two can be non-zero
    
    return app_pos_energy, app_neg_energy, app_soc 

def constrain_pv(model, battery_init, battery_max, energy_rate, eff, duration, name: str):
    """
    Build the optimization constraints for the PV system.
    """
    battery_pos_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=0, ub=energy_rate, name=name+"_pos_battery_charge") 
    battery_neg_energy = model.addVars(duration, vtype=gp.GRB.CONTINUOUS, lb=-energy_rate, ub=0, name=name+"_neg_battery_charge") 
    battery_soc = model.addVars(duration+1, vtype=gp.GRB.CONTINUOUS, lb=0, ub=battery_max, name=name+"battery_soc")

    # initialize the battery soc
    model.addConstr(battery_soc[0] == battery_init, name=name+"_battery_soc_init")
    # model.addConstr(battery_soc[duration] == battery_init, name=name+"_battery_soc_end")
    for t in range(duration):
        # transition function of soc
        model.addConstr(battery_soc[t+1] == battery_pos_energy[t]*eff + battery_neg_energy[t]/eff + battery_soc[t], name=name+f"_battery_soc_constr_{t}")

        # constraint: the aggregation of total demand and energy charged into the battery should be greater than pv
        # model.addConstr(pv_pred[t] - demand[t] <= battery_pos_energy[t] + battery_neg_energy[t], name=name+f"_battery_pv_{t}")
        # constraint: at each time step, the battery can only charge or discharge
        model.addConstr(battery_pos_energy[t] * battery_neg_energy[t] == 0, name=name+f"_battery_pos_neg_constr_{t}")

    return battery_pos_energy, battery_neg_energy, battery_soc

def get_profile(var, row, col, type='nonflex'):
    """
    Get the profile of a gurobi variable.
    row: number of cycles
    col: number of time steps
    """
    if type == 'nonflex':
        return [sum(var[i, t].X for i in range(row)) for t in range(col)]
    
    if type == 'flex':
        return [var[t].X for t in range(col)]

def get_tolerance(cyc_start, cyc_profile, duration, max_delay=24):
    """
    Get the tolerance for the operation cycles.
    The tolerance is the maximum delay allowed for each cycle.
    """
    tolerance = [] # list of tolerances for each cycle
    n_cyc = len(cyc_start) # number of cycles

    if n_cyc == 0:
        return tolerance
    
    for i in range(n_cyc-1):
        len_cyc = len(cyc_profile[i])
        gap = cyc_start[i+1] - (cyc_start[i] + len_cyc)
        if gap > max_delay: # maximum tolerance is 6 hours
                tolerance.append(max_delay)
        else:
                tolerance.append(gap)
    # the last cycle can be delayed until the end of the day
    len_cyc = len(cyc_profile[-1])
    gap = duration - (cyc_start[-1] + len_cyc) 
    if gap > max_delay:
        tolerance.append(max_delay)
    else:
        tolerance.append(gap)
    
    return tolerance

# %% [markdown]
# load the houldhold data and the dynamic price

# %%
household = pd.read_csv('summer_household_energydata.csv', index_col=0)
duration = 24 * 4  # 24 hours, 15 minutes per time step per day
n_days = household.shape[0] // duration

# initial time series
critical_tot = np.array(household['Critical Appliances'])
wm_tot = np.array(household['Washing Machine'])
dishwasher_tot = np.array(household['Dishwasher'])
pv_tot = np.array(household['PV']) # The assumption is that our prediction of pv generation is 100% accurate
price = np.array(household['Dynamic Price']) / 1000 # convert to euro/kWh

# -------------------- settings -------------------- #
# pv
pv_battery_max = 16 # battery capacity in kWh
pv_battery_energy_rate = 1 # kWh
pv_battery_init = 0 # random
pv_battery_eff = 0.95 # efficiency of the battery charging/discharging process

# ev
home_charger = 4 # maximum power of home charger in kW
energy_rate = home_charger / 4 # maximum amout of energy that can be charged in 15 minutes
ev_in = 24 # plug in at 2016-05-01 18:00
ev_out = 88 # plug out at 2016-05-02 10:00

soc_max = 67 # ev battery capacity in kWh taken from the Tesla Model Y
soc_demand = 6 # energy demand of the EV in kWh, the assumption is that the EV is fully charged at the end of the day
soc_init = soc_max - soc_demand
ev_eff = 0.95 # efficiency of the EV charging/discharging process

# price
price_penalty = 0.1 # tuning parameter for the price penalty
power_th = 3 # threshold for peak load in kW

# %% [markdown]
# Benchmark

# %%
cost_benchmark = []

for day in range(n_days):
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day
        
    tot_demand = dishwasher_ini + critical_ini + wm_ini + ev_ini
    cost_per_day = np.dot(tot_demand, price_ini) + price_penalty * np.sum(tot_demand[tot_demand > power_th/4]) # cost of the benchmark scenarioeuro')
    cost_benchmark.append(cost_per_day)
print('Cost benchmark: ', cost_benchmark, 'euro')
# Out:
# Cost benchmark:  [1.3856412599999999, 1.28336296, 1.0647579600000001, 1.1820179, 1.17091506, 1.39229425, 1.2430541800000001] euro

# %% [markdown]
# Scenario 1: unidirectional EV only

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario1 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario1 = []

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 1 #########################
    # Create a Gurobi model
    model1 = gp.Model(f"Scenario 1: uni EV, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        print(f"day {day}, wm_cyc_start:{wm_cyc_start}")
        wm_energy, _ = constrain_nonflex(model1, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model1.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model1, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model1.update()

    # EV related variables
    ev_pos_energy, ev_neg_energy, ev_soc = constrain_flex(model1, soc_init, soc_demand, soc_max, energy_rate, 0, ev_eff, ev_in, ev_out, duration, "ev")
    model1.update()


    tot_demand = [] # add profiles of all cycles together to get the final wm power profile
    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += ev_pos_energy[t] + ev_neg_energy[t] + critical_ini[t]
        model1.addConstr(demand >= 0, name=f"demand_nonneg_{t}") # ensure that the demand is non-negative

        tot_demand.append(demand) 

    # Now deal with the objective function considering the violation of power threshold
    excess = model1.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model1.addConstr(
            excess[t] >= tot_demand[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model1.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model1.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    # cost part 1: cost of the energy consumed 
    # after you’ve set up penalty_flag[t] exactly as before…

    # Build a single “effective price” per t:
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * tot_demand[t]
        for t in range(duration)
    )

    # cost = gp.quicksum(tot_demand[t] * price[t] for t in range(duration))

    model1.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model1.optimize()
    
    
    # Check the optimization status
    if model1.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model1.objVal)

        cost_scenario1.append(model1.objVal)
        
        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario1.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario1.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        ev_pos_opt = get_profile(ev_pos_energy, duration, duration, type='flex')
        ev_neg_opt = get_profile(ev_neg_energy, duration, duration, type='flex')
        data_scenario1.loc[day*duration:(day+1)*duration-1, 'ev'] = np.array(ev_pos_opt) + np.array(ev_neg_opt)
        data_scenario1.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini
    
    else:
        print("No optimal solution found. Status code:", model1.status)

    # print(day)
# Out:
# days: 0
# day 0, wm_cyc_start:[79]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 833 columns and 3337 nonzeros
# Model fingerprint: 0xde972a07
# Model has 384 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 545 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [4e-03, 7e+01]
# Presolve removed 514 rows and 638 columns
# Presolve time: 0.00s
# Presolved: 204 rows, 297 columns, 766 nonzeros
# Variable types: 198 continuous, 99 integer (99 binary)
# Found heuristic solution: objective 0.5468968
# Found heuristic solution: objective 0.5460695
#
# Root relaxation: objective 5.392016e-01, 78 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.53920    0    5    0.54607    0.53920  1.26%     -    0s
#      0     0    0.53968    0    5    0.54607    0.53968  1.17%     -    0s
# H    0     0                       0.5441954    0.53968  0.83%     -    0s
#      0     0          -    0         0.54420    0.54418  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 3
#   MIR: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (82 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.544195 0.54607 0.546897
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.441954184211e-01, best bound 5.441771394737e-01, gap 0.0034%
# Optimal solution found.
# Objective value (cost): 0.5441954184210526
# days: 1
# day 1, wm_cyc_start:[1]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 833 columns and 3595 nonzeros
# Model fingerprint: 0xd8f01882
# Model has 384 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 545 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 492 rows and 598 columns
# Presolve time: 0.01s
# Presolved: 233 rows, 344 columns, 1133 nonzeros
# Variable types: 222 continuous, 122 integer (119 binary)
# Found heuristic solution: objective 0.7047125
#
# Root relaxation: objective 6.945130e-01, 97 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.6945130    0.69451  0.00%     -    0s
#
# Explored 1 nodes (97 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.694513 0.704713
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.945130094737e-01, best bound 6.945130094737e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.6945130094736844
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 449 columns and 994 nonzeros
# Model fingerprint: 0x914ab126
# Model has 192 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 353 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 353 rows and 321 columns
# Presolve time: 0.00s
# Presolved: 129 rows, 192 columns, 384 nonzeros
# Variable types: 128 continuous, 64 integer (64 binary)
# Found heuristic solution: objective 0.5437344
#
# Root relaxation: objective 5.436368e-01, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.54364    0    1    0.54373    0.54364  0.02%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.543734
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.437344447368e-01, best bound 5.437344447368e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5437344447368421
# days: 3
# day 3, wm_cyc_start:[84]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 517 rows, 641 columns and 2383 nonzeros
# Model fingerprint: 0x1cfc6ebe
# Model has 288 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 449 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve removed 452 rows and 512 columns
# Presolve time: 0.00s
# Presolved: 133 rows, 197 columns, 400 nonzeros
# Variable types: 128 continuous, 69 integer (69 binary)
# Found heuristic solution: objective 0.5338992
#
# Root relaxation: cutoff, 13 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.53390    0.53390  0.00%     -    0s
#
# Explored 1 nodes (13 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.533899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.338991794737e-01, best bound 5.338991794737e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5338991794736843
# days: 4
# day 4, wm_cyc_start:[7, 19, 81, 88]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 916 rows, 1409 columns and 7562 nonzeros
# Model fingerprint: 0x1b925d9a
# Model has 672 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 833 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 8e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [2e-02, 7e+01]
# Presolve removed 775 rows and 1157 columns
# Presolve time: 0.01s
# Presolved: 280 rows, 391 columns, 1480 nonzeros
# Variable types: 273 continuous, 118 integer (118 binary)
# Found heuristic solution: objective 1.1604734
# Found heuristic solution: objective 0.9692495
#
# Root relaxation: objective 9.382686e-01, 150 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.93827    0    3    0.96925    0.93827  3.20%     -    0s
# H    0     0                       0.9476971    0.93827  0.99%     -    0s
#      0     0    0.93910    0    4    0.94770    0.93910  0.91%     -    0s
#      0     0    0.93910    0   28    0.94770    0.93910  0.91%     -    0s
# H    0     0                       0.9438397    0.93910  0.50%     -    0s
# H    0     0                       0.9431217    0.93910  0.43%     -    0s
# H    0     0                       0.9417905    0.93910  0.29%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Implied bound: 5
#   GUB cover: 1
#   Relax-and-lift: 3
#
# Explored 1 nodes (243 simplex iterations) in 0.08 seconds (0.02 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.941791 0.943122 0.94384 ... 1.16047
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.417905352632e-01, best bound 9.417755284107e-01, gap 0.0016%
# Optimal solution found.
# Objective value (cost): 0.9417905352631581
# days: 5
# day 5, wm_cyc_start:[20, 36, 74]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 717 rows, 1025 columns and 4191 nonzeros
# Model fingerprint: 0x0db73f75
# Model has 480 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 641 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 592 rows and 788 columns
# Presolve time: 0.01s
# Presolved: 250 rows, 362 columns, 1100 nonzeros
# Variable types: 242 continuous, 120 integer (120 binary)
# Found heuristic solution: objective 0.6505543
# Found heuristic solution: objective 0.6448950
#
# Root relaxation: objective 6.423272e-01, 81 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.64233    0    3    0.64489    0.64233  0.40%     -    0s
# *    0     0               0       0.6435442    0.64354  0.00%     -    0s
#
# Explored 1 nodes (86 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.643544 0.644895 0.650554
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.435442447368e-01, best bound 6.435442447368e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.6435442447368422
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 449 columns and 994 nonzeros
# Model fingerprint: 0x3af44cdb
# Model has 192 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 353 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve removed 353 rows and 321 columns
# Presolve time: 0.00s
# Presolved: 129 rows, 192 columns, 384 nonzeros
# Variable types: 128 continuous, 64 integer (64 binary)
# Found heuristic solution: objective 0.5328812
#
# Root relaxation: cutoff, 11 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         0.53288    0.53288  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 0.532881
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.328811626316e-01, best bound 5.328811626316e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5328811626315791

# %%
print(cost_scenario1)
data_scenario1.to_csv('output/winter_scenario1.csv')
# Out:
# [0.5441954184210526, 0.6945130094736844, 0.5437344447368421, 0.5338991794736843, 0.9417905352631581, 0.6435442447368422, 0.5328811626315791]

# %% [markdown]
# Scenario 2: bidirectional EV

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario2 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario2 = []

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 1 #########################
    # Create a Gurobi model
    model2 = gp.Model(f"Scenario 2: bi EV, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        print(f"day {day}, wm_cyc_start:{wm_cyc_start}")
        wm_energy, _ = constrain_nonflex(model2, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model2.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model2, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model2.update()

    # EV related variables
    ev_pos_energy, ev_neg_energy, ev_soc = constrain_flex(model2, soc_init, soc_demand, soc_max, energy_rate, -energy_rate, ev_eff, ev_in, ev_out, duration, "ev")
    model2.update()


    tot_demand = [] # add profiles of all cycles together to get the final wm power profile
    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += ev_pos_energy[t] + ev_neg_energy[t] + critical_ini[t]
        model2.addConstr(demand >= 0, name=f"demand_nonneg_{t}") # ensure that the demand is non-negative
        tot_demand.append(demand) 

    # Now deal with the objective function considering the violation of power threshold
    excess = model2.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model2.addConstr(
            excess[t] >= tot_demand[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model2.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model2.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    # cost part 1: cost of the energy consumed 
    # after you’ve set up penalty_flag[t] exactly as before…

    # Build a single “effective price” per t:
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * tot_demand[t]
        for t in range(duration)
    )

    # cost = gp.quicksum(tot_demand[t] * price[t] for t in range(duration))

    model2.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model2.optimize()
    
    
    # Check the optimization status
    if model2.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model2.objVal)

        cost_scenario2.append(model2.objVal)

        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario2.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario2.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        ev_pos_opt = get_profile(ev_pos_energy, duration, duration, type='flex')
        ev_neg_opt = get_profile(ev_neg_energy, duration, duration, type='flex')
        data_scenario2.loc[day*duration:(day+1)*duration-1, 'ev'] = np.array(ev_pos_opt) + np.array(ev_neg_opt)
        data_scenario2.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini

    else:
        print("No optimal solution found. Status code:", model2.status)

    # print(day)
# Out:
# days: 0
# day 0, wm_cyc_start:[79]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 833 columns and 3337 nonzeros
# Model fingerprint: 0xb3daf0b8
# Model has 384 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 545 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [4e-03, 7e+01]
# Presolve removed 295 rows and 456 columns
# Presolve time: 0.01s
# Presolved: 486 rows, 542 columns, 1650 nonzeros
# Variable types: 380 continuous, 162 integer (162 binary)
# Found heuristic solution: objective 0.5351162
# Found heuristic solution: objective 0.5336527
#
# Root relaxation: objective -2.888196e-02, 494 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.02888    0   96    0.53365   -0.02888   105%     -    0s
#      0     0    0.48094    0   24    0.53365    0.48094  9.88%     -    0s
# H    0     0                       0.5243633    0.49213  6.15%     -    0s
# H    0     0                       0.5214704    0.49213  5.63%     -    0s
#      0     0    0.49213    0   22    0.52147    0.49213  5.63%     -    0s
# H    0     0                       0.5079780    0.49213  3.12%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 27
#   Cover: 1
#   MIR: 15
#   Flow cover: 33
#   RLT: 24
#   BQP: 1
#
# Explored 1 nodes (733 simplex iterations) in 0.09 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.507978 0.52147 0.524363 ... 0.535116
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.079779736842e-01, best bound 5.079779736842e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5079779736842104
# days: 1
# day 1, wm_cyc_start:[1]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 616 rows, 833 columns and 3595 nonzeros
# Model fingerprint: 0x8a24ef87
# Model has 384 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 545 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 273 rows and 416 columns
# Presolve time: 0.01s
# Presolved: 515 rows, 589 columns, 2018 nonzeros
# Variable types: 404 continuous, 185 integer (182 binary)
# Found heuristic solution: objective 0.6855465
#
# Root relaxation: objective 1.448832e-01, 542 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.14488    0   85    0.68555    0.14488  78.9%     -    0s
# H    0     0                       0.6583821    0.63662  3.30%     -    0s
#      0     0    0.63662    0   22    0.65838    0.63662  3.30%     -    0s
# H    0     0                       0.6481413    0.64288  0.81%     -    0s
#      0     0          -    0         0.64814    0.64814  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 28
#   MIR: 15
#   Flow cover: 27
#   RLT: 38
#
# Explored 1 nodes (853 simplex iterations) in 0.08 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.648141 0.658382 0.685547
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.481413411250e-01, best bound 6.481382338776e-01, gap 0.0005%
# Optimal solution found.
# Objective value (cost): 0.6481413411250002
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 449 columns and 994 nonzeros
# Model fingerprint: 0x123d6271
# Model has 192 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 353 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 171 rows and 139 columns
# Presolve time: 0.00s
# Presolved: 374 rows, 437 columns, 1126 nonzeros
# Variable types: 310 continuous, 127 integer (127 binary)
# Found heuristic solution: objective 0.5437344
#
# Root relaxation: objective 4.954906e-01, 138 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.49549    0    1    0.54373    0.49549  8.87%     -    0s
# *    0     0               0       0.4959133    0.49591  0.00%     -    0s
#
# Explored 1 nodes (140 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.495913 0.543734
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.959133155956e-01, best bound 4.959133155956e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.4959133155955685
# days: 3
# day 3, wm_cyc_start:[84]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 517 rows, 641 columns and 2383 nonzeros
# Model fingerprint: 0xef75c542
# Model has 288 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 449 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve removed 267 rows and 330 columns
# Presolve time: 0.01s
# Presolved: 381 rows, 442 columns, 1154 nonzeros
# Variable types: 310 continuous, 132 integer (132 binary)
# Found heuristic solution: objective 0.5338992
#
# Root relaxation: objective 4.739861e-01, 150 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.47399    0    7    0.53390    0.47399  11.2%     -    0s
# H    0     0                       0.5025161    0.47399  5.68%     -    0s
# H    0     0                       0.5002327    0.47399  5.25%     -    0s
#      0     0     cutoff    0         0.50023    0.50023  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 3
#   Implied bound: 1
#   MIR: 3
#   Flow cover: 2
#   RLT: 2
#
# Explored 1 nodes (160 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.500233 0.502516 0.533899
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.002327252355e-01, best bound 5.002327252355e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5002327252354578
# days: 4
# day 4, wm_cyc_start:[7, 19, 81, 88]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 916 rows, 1409 columns and 7562 nonzeros
# Model fingerprint: 0x008a6de4
# Model has 672 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 833 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 8e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [2e-02, 7e+01]
# Presolve removed 545 rows and 973 columns
# Presolve time: 0.01s
# Presolved: 576 rows, 641 columns, 2413 nonzeros
# Variable types: 458 continuous, 183 integer (183 binary)
# Found heuristic solution: objective 0.9773254
# Found heuristic solution: objective 0.9717827
# Found heuristic solution: objective 0.8587015
#
# Root relaxation: objective 4.235179e-02, 647 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.04235    0  102    0.85870    0.04235  95.1%     -    0s
#      0     0    0.78854    0   43    0.85870    0.78854  8.17%     -    0s
# H    0     0                       0.8464456    0.79381  6.22%     -    0s
# H    0     0                       0.8456038    0.79831  5.59%     -    0s
#      0     0    0.79831    0   40    0.84560    0.79831  5.59%     -    0s
#      0     0    0.79833    0   40    0.84560    0.79833  5.59%     -    0s
# H    0     0                       0.8313280    0.83091  0.05%     -    0s
#      0     0    0.83095    0   12    0.83133    0.83095  0.05%     -    0s
#      0     0    0.83095    0    8    0.83133    0.83095  0.05%     -    0s
#      0     0          -    0         0.83133    0.83126  0.01%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 15
#   Cover: 2
#   Implied bound: 1
#   MIR: 18
#   Flow cover: 12
#   RLT: 39
#   Relax-and-lift: 3
#
# Explored 1 nodes (977 simplex iterations) in 0.11 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.831328 0.845604 0.846446 ... 0.977325
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.313279752500e-01, best bound 8.312642443600e-01, gap 0.0077%
# Optimal solution found.
# Objective value (cost): 0.8313279752499994
# days: 5
# day 5, wm_cyc_start:[20, 36, 74]
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 717 rows, 1025 columns and 4191 nonzeros
# Model fingerprint: 0x1d000999
# Model has 480 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 641 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [3e-02, 7e+01]
# Presolve removed 350 rows and 606 columns
# Presolve time: 0.01s
# Presolved: 555 rows, 607 columns, 2075 nonzeros
# Variable types: 424 continuous, 183 integer (183 binary)
# Found heuristic solution: objective 0.6329237
# Found heuristic solution: objective 0.6270577
#
# Root relaxation: objective 1.327413e-01, 658 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.13274    0  119    0.62706    0.13274  78.8%     -    0s
#      0     0    0.54955    0   61    0.62706    0.54955  12.4%     -    0s
# H    0     0                       0.6200963    0.55770  10.1%     -    0s
#      0     0    0.55770    0   60    0.62010    0.55770  10.1%     -    0s
# H    0     0                       0.6166695    0.58827  4.60%     -    0s
#      0     0    0.58827    0   42    0.61667    0.58827  4.60%     -    0s
# H    0     0                       0.6088063    0.58861  3.32%     -    0s
# H    0     0                       0.6087618    0.58861  3.31%     -    0s
#      0     0    0.58924    0   37    0.60876    0.58924  3.21%     -    0s
#      0     0    0.59391    0   22    0.60876    0.59391  2.44%     -    0s
# H    0     0                       0.6036333    0.59394  1.61%     -    0s
#      0     0    0.59448    0   22    0.60363    0.59448  1.52%     -    0s
# H    0     0                       0.6006855    0.59448  1.03%     -    0s
# *    0     0               0       0.5974566    0.59746  0.00%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 25
#   MIR: 33
#   Flow cover: 70
#   RLT: 27
#   Relax-and-lift: 1
#
# Explored 1 nodes (1221 simplex iterations) in 0.16 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 9: 0.597457 0.600685 0.603633 ... 0.632924
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.974566099169e-01, best bound 5.974566099169e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.5974566099168981
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 418 rows, 449 columns and 994 nonzeros
# Model fingerprint: 0x1687695d
# Model has 192 quadratic objective terms
# Model has 64 quadratic constraints
# Variable types: 353 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-03, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [5e-02, 7e+01]
# Presolve removed 171 rows and 139 columns
# Presolve time: 0.00s
# Presolved: 374 rows, 437 columns, 1126 nonzeros
# Variable types: 310 continuous, 127 integer (127 binary)
# Found heuristic solution: objective 0.5328812
#
# Root relaxation: objective 4.922037e-01, 131 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.4922037    0.49220  0.00%     -    0s
#
# Explored 1 nodes (131 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.492204 0.532881
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.922037100554e-01, best bound 4.922037100554e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.49220371005540164

# %%
print(cost_scenario2)
data_scenario2.to_csv('output/winter_scenario2.csv', index=False)
# Out:
# [0.5079779736842104, 0.6481413411250002, 0.4959133155955685, 0.5002327252354578, 0.8313279752499994, 0.5974566099168981, 0.49220371005540164]

# %% [markdown]
# Scenario 3: PV + Battery, Dummy EV

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario3 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario3 = []

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 3 #########################
    # Create a Gurobi model
    model3 = gp.Model(f"Scenario 3: PV+BESS, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        wm_energy, _ = constrain_nonflex(model3, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model3.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model3, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model3.update()

    # PV and BESS related variables
    battery_pos_energy, battery_neg_energy, _ = constrain_pv(model3, pv_battery_init, pv_battery_max, pv_battery_energy_rate, pv_battery_eff, duration, 'pv')
    model3.update()

    tot_demand = [] # add profiles of all cycles together to get the final wm power profile
    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += critical_ini[t] + ev_ini[t]
        demand += battery_pos_energy[t] + battery_neg_energy[t] - pv_ini[t] # the energy demand is the sum of the washing machine, dishwasher, critical appliances, EV and the battery
        model3.addConstr(demand >= 0, name=f"demand_nonneg_{t}") # ensure that the demand is non-negative
        tot_demand.append(demand) 



    # Now deal with the objective function considering the violation of power threshold
    excess = model3.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model3.addConstr(
            excess[t] >= tot_demand[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model3.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model3.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * tot_demand[t]
        for t in range(duration)
    )
    model3.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model3.optimize()

    # Check the optimization status
    if model3.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model3.objVal)
        cost_scenario3.append(model3.objVal)

        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario3.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario3.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        bess_pos_opt = get_profile(battery_pos_energy, duration, duration, type='flex')
        bess_neg_opt = get_profile(battery_neg_energy, duration, duration, type='flex')
        data_scenario3.loc[day*duration:(day+1)*duration-1, 'pv_bess'] = np.array(bess_pos_opt) + np.array(bess_neg_opt)
        data_scenario3.loc[day*duration:(day+1)*duration-1, 'ev'] = ev_ini
        data_scenario3.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini

    else:
        print("No optimal solution found. Status code:", model3.status)
# Out:
# days: 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 583 rows, 865 columns and 3400 nonzeros
# Model fingerprint: 0x651d9181
# Model has 384 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 577 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [6e-04, 1e-01]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [9e-03, 1e+00]
# Presolve removed 166 rows and 366 columns
# Presolve time: 0.01s
# Presolved: 638 rows, 720 columns, 2115 nonzeros
# Variable types: 509 continuous, 211 integer (211 binary)
# Found heuristic solution: objective 0.4613087
# Found heuristic solution: objective 0.4577564
# Found heuristic solution: objective 0.4421313
#
# Root relaxation: objective -3.026001e-01, 434 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.30260    0  103    0.44213   -0.30260   168%     -    0s
# H    0     0                       0.3330879   -0.30260   191%     -    0s
# H    0     0                       0.3311539    0.31438  5.07%     -    0s
# H    0     0                       0.3269754    0.31438  3.85%     -    0s
# H    0     0                       0.3203189    0.31438  1.85%     -    0s
#      0     0    0.31438    0   20    0.32032    0.31438  1.85%     -    0s
#      0     0    0.31969    0    8    0.32032    0.31969  0.20%     -    0s
# H    0     0                       0.3199469    0.31969  0.08%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 15
#   Cover: 1
#   MIR: 10
#   Flow cover: 56
#   RLT: 23
#   Relax-and-lift: 2
#
# Explored 1 nodes (733 simplex iterations) in 0.10 seconds (0.03 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: 0.319947 0.320319 0.326975 ... 0.461309
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.199468653116e-01, best bound 3.199468653116e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.31994686531163374
# days: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 583 rows, 865 columns and 3658 nonzeros
# Model fingerprint: 0xf2e5b2d9
# Model has 384 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 577 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-04, 1e-01]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [2e-03, 1e+00]
# Presolve removed 117 rows and 317 columns
# Presolve time: 0.01s
# Presolved: 707 rows, 789 columns, 2592 nonzeros
# Variable types: 560 continuous, 229 integer (229 binary)
# Found heuristic solution: objective 0.5535897
# Found heuristic solution: objective 0.5482321
#
# Root relaxation: objective -2.188856e-01, 680 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.21889    0  129    0.54823   -0.21889   140%     -    0s
#      0     0    0.39330    0   60    0.54823    0.39330  28.3%     -    0s
#      0     0    0.39466    0   59    0.54823    0.39466  28.0%     -    0s
# H    0     0                       0.5126337    0.48334  5.71%     -    0s
#      0     0    0.48334    0   11    0.51263    0.48334  5.71%     -    0s
# H    0     0                       0.5105124    0.48393  5.21%     -    0s
# H    0     0                       0.4945226    0.48850  1.22%     -    0s
#      0     0    0.48850    0    6    0.49452    0.48850  1.22%     -    0s
#      0     0    0.48850    0    6    0.49452    0.48850  1.22%     -    0s
# *    0     0               0       0.4942688    0.49427  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 16
#   Cover: 2
#   Implied bound: 4
#   MIR: 23
#   Flow cover: 30
#   RLT: 62
#   Relax-and-lift: 5
#
# Explored 1 nodes (1276 simplex iterations) in 0.12 seconds (0.06 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.494269 0.494523 0.510512 ... 0.55359
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.942688350799e-01, best bound 4.942688350799e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.49426883507991637
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 385 rows, 481 columns and 1057 nonzeros
# Model fingerprint: 0xe5f55de5
# Model has 192 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 385 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [9e-04, 1e-01]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e-02, 2e+00]
# Presolve removed 73 rows and 82 columns
# Presolve time: 0.00s
# Presolved: 476 rows, 563 columns, 1424 nonzeros
# Variable types: 399 continuous, 164 integer (164 binary)
# Found heuristic solution: objective 0.4497703
#
# Root relaxation: objective 2.964188e-01, 144 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.29642    0   13    0.44977    0.29642  34.1%     -    0s
# H    0     0                       0.3015082    0.29642  1.69%     -    0s
#      0     0          -    0         0.30151    0.30149  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 5
#   Flow cover: 7
#   Relax-and-lift: 4
#
# Explored 1 nodes (223 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 0.301508 0.44977
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.015082011176e-01, best bound 3.014882626676e-01, gap 0.0066%
# Optimal solution found.
# Objective value (cost): 0.3015082011175892
# days: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 484 rows, 673 columns and 2446 nonzeros
# Model fingerprint: 0x3bb8e5e6
# Model has 288 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 481 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [4e-04, 1e-01]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [4e-03, 1e+00]
# Presolve removed 130 rows and 230 columns
# Presolve time: 0.01s
# Presolved: 543 rows, 632 columns, 1642 nonzeros
# Variable types: 442 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 0.4183824
#
# Root relaxation: objective 2.501525e-01, 188 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.25015    0   23    0.41838    0.25015  40.2%     -    0s
# H    0     0                       0.3842300    0.25015  34.9%     -    0s
# H    0     0                       0.2830773    0.25015  11.6%     -    0s
#      0     0    0.27981    0    2    0.28308    0.27981  1.15%     -    0s
# H    0     0                       0.2807463    0.28075  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 5
#   Flow cover: 15
#   RLT: 5
#   Relax-and-lift: 1
#   PSD: 1
#
# Explored 1 nodes (280 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.280746 0.283077 0.38423 0.418382
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.807462831856e-01, best bound 2.807462831856e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.28074628318559475
# days: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 883 rows, 1441 columns and 7625 nonzeros
# Model fingerprint: 0xe08c9641
# Model has 672 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 865 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [5e-04, 2e-01]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e-03, 2e+01]
# Presolve removed 369 rows and 841 columns
# Presolve time: 0.02s
# Presolved: 795 rows, 881 columns, 3057 nonzeros
# Variable types: 621 continuous, 260 integer (260 binary)
# Found heuristic solution: objective 1.2609347
# Found heuristic solution: objective 1.2550651
# Found heuristic solution: objective 0.8582356
#
# Root relaxation: objective -5.889358e-02, 768 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.05889    0  141    0.85824   -0.05889   107%     -    0s
# H    0     0                       0.8052714    0.64437  20.0%     -    0s
#      0     0    0.64437    0   66    0.80527    0.64437  20.0%     -    0s
# H    0     0                       0.7666951    0.64973  15.3%     -    0s
# H    0     0                       0.7657024    0.64973  15.1%     -    0s
# H    0     0                       0.7640866    0.68307  10.6%     -    0s
#      0     0    0.68307    0   59    0.76409    0.68307  10.6%     -    0s
# H    0     0                       0.7450146    0.68307  8.32%     -    0s
#      0     0    0.72998    0   20    0.74501    0.72998  2.02%     -    0s
# H    0     0                       0.7359730    0.73314  0.39%     -    0s
#      0     0    0.73314    0   16    0.73597    0.73314  0.39%     -    0s
# H    0     0                       0.7359366    0.73314  0.38%     -    0s
# H    0     0                       0.7349649    0.73316  0.25%     -    0s
#      0     0    0.73316    0   16    0.73496    0.73316  0.25%     -    0s
# H    0     0                       0.7349215    0.73316  0.24%     -    0s
# H    0     0                       0.7347744    0.73316  0.22%     -    0s
#      0     0    0.73338    0    7    0.73477    0.73338  0.19%     -    0s
#      0     0    0.73338    0    7    0.73477    0.73338  0.19%     -    0s
# H    0     0                       0.7346181    0.73416  0.06%     -    0s
#      0     0    0.73416    0    3    0.73462    0.73416  0.06%     -    0s
#      0     0    0.73422    0    1    0.73462    0.73422  0.05%     -    0s
# H    0     0                       0.7343764    0.73422  0.02%     -    0s
#      0     0     cutoff    0         0.73438    0.73438  0.00%     -    0s
#
# Cutting planes:
#   Learned: 7
#   Gomory: 21
#   Cover: 3
#   Implied bound: 8
#   MIR: 39
#   Flow cover: 52
#   RLT: 32
#   Relax-and-lift: 4
#   PSD: 2
#
# Explored 1 nodes (1232 simplex iterations) in 0.20 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.734376 0.734618 0.734774 ... 0.766695
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.343764213161e-01, best bound 7.343764213161e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.7343764213160666
# days: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 684 rows, 1057 columns and 4254 nonzeros
# Model fingerprint: 0x6895b708
# Model has 480 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 673 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [6e-04, 1e-01]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e-02, 1e+01]
# Presolve removed 172 rows and 463 columns
# Presolve time: 0.01s
# Presolved: 774 rows, 856 columns, 2741 nonzeros
# Variable types: 604 continuous, 252 integer (252 binary)
# Found heuristic solution: objective 0.5558517
# Found heuristic solution: objective 0.5473261
#
# Root relaxation: objective -1.625185e-01, 628 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.16252    0  162    0.54733   -0.16252   130%     -    0s
# H    0     0                       0.5451698   -0.16252   130%     -    0s
# H    0     0                       0.5240207   -0.16252   131%     -    0s
# H    0     0                       0.5159287    0.41443  19.7%     -    0s
#      0     0    0.42645    0   61    0.51593    0.42645  17.3%     -    0s
# H    0     0                       0.5070831    0.42645  15.9%     -    0s
# H    0     0                       0.5068070    0.42645  15.9%     -    0s
# H    0     0                       0.5050240    0.44050  12.8%     -    0s
#      0     0    0.44050    0   54    0.50502    0.44050  12.8%     -    0s
#      0     0    0.44085    0   54    0.50502    0.44085  12.7%     -    0s
# H    0     0                       0.4872827    0.44085  9.53%     -    0s
#      0     0    0.47085    0   20    0.48728    0.47085  3.37%     -    0s
#      0     0    0.47415    0   20    0.48728    0.47415  2.70%     -    0s
# H    0     0                       0.4854690    0.47415  2.33%     -    0s
# H    0     0                       0.4840701    0.47415  2.05%     -    0s
# H    0     0                       0.4840221    0.47608  1.64%     -    0s
#      0     0    0.47608    0   13    0.48402    0.47608  1.64%     -    0s
#      0     0    0.47883    0   12    0.48402    0.47883  1.07%     -    0s
#      0     0    0.48119    0   10    0.48402    0.48119  0.59%     -    0s
#      0     0    0.48235    0    8    0.48402    0.48235  0.35%     -    0s
#      0     0          -    0         0.48402    0.48398  0.01%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 36
#   Cover: 2
#   Implied bound: 14
#   Clique: 5
#   MIR: 49
#   Flow cover: 74
#   RLT: 29
#   Relax-and-lift: 4
#   BQP: 4
#   PSD: 1
#
# Explored 1 nodes (1293 simplex iterations) in 0.20 seconds (0.08 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 0.484022 0.48407 0.485469 ... 0.54517
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.840220875956e-01, best bound 4.839766671468e-01, gap 0.0094%
# Optimal solution found.
# Objective value (cost): 0.48402208759556764
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 385 rows, 481 columns and 1057 nonzeros
# Model fingerprint: 0x6b9add8c
# Model has 192 quadratic objective terms
# Model has 96 quadratic constraints
# Variable types: 385 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [9e-04, 1e-01]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [1e-02, 1e+00]
# Presolve removed 25 rows and 25 columns
# Presolve time: 0.00s
# Presolved: 545 rows, 641 columns, 1631 nonzeros
# Variable types: 456 continuous, 185 integer (185 binary)
# Found heuristic solution: objective 0.4418432
#
# Root relaxation: objective 3.137143e-01, 176 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.31371    0    8    0.44184    0.31371  29.0%     -    0s
# H    0     0                       0.3204281    0.31371  2.10%     -    0s
# H    0     0                       0.3176298    0.31371  1.23%     -    0s
# H    0     0                       0.3166658    0.31578  0.28%     -    0s
#
# Cutting planes:
#   MIR: 1
#   Flow cover: 3
#
# Explored 1 nodes (176 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.316666 0.31763 0.320428 0.441843
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.166657966274e-01, best bound 3.166657966274e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.3166657966274232

# %%
print(cost_scenario3)
data_scenario3.to_csv('output/winter_scenario3.csv', index=False)
# Out:
# [0.31994686531163374, 0.49426883507991637, 0.3015082011175892, 0.28074628318559475, 0.7343764213160666, 0.48402208759556764, 0.3166657966274232]

# %% [markdown]
# Benchmark: w/o PV, w/o demand response
# meaning EV is charged using the dumb charging strategy. The penalty works in the following way: if the total load exceeds the threshold, the price will become the product of the maximum price and a tuning parameter.

# %% [markdown]
# Scenario 4: All together

# %%
# Initialize the data structure in order to store the optimal profiles
data_scenario4 = pd.DataFrame(
    0,
    index=range(duration*n_days),  # 7 days in a week
    columns=['wm', 'dw', 'pv_bess', 'ev', 'critical']
)

cost_scenario4 = []

for day in range(n_days):
    print("days:", day)
    wm_ini = wm_tot[day*duration:(day+1)*duration] # washing machine profile for the current day
    dishwasher_ini = dishwasher_tot[day*duration:(day+1)*duration] # dishwasher profile for the current day
    pv_ini = pv_tot[day*duration:(day+1)*duration] # pv profile for the current day
    critical_ini = critical_tot[day*duration:(day+1)*duration] # critical appliances profile for the current day
    ev_ini = np.zeros(duration) # initialize the EV profile
    ev_ini[ev_in:ev_in+int(np.ceil(soc_demand/energy_rate))] = energy_rate # dumb charging of EV, charging at 4 kW starting at 18:00 to fill the depletion of 6 kWh

    price_ini = price[day*duration:(day+1)*duration] # price profile for the current day

    wm_cyc_start, wm_cyc_profile = extract_cyc(wm_ini) # start times and profiles of the cycles
    dw_cyc_start, dw_cyc_profile = extract_cyc(dishwasher_ini) # start times and profiles of the cycles

    # determin the tolerance for the washing machine and dishwasher cycles
    wm_tolerance = get_tolerance(wm_cyc_start, wm_cyc_profile, duration)
    dw_tolerance = get_tolerance(dw_cyc_start, dw_cyc_profile, duration)
    
    #########################  Scenario 4 #########################
    # Create a Gurobi model
    model4 = gp.Model(f"Scenario 4: All together, day{day+1}")

    # Washing machine related variables
    if wm_cyc_start:
        wm_energy, _ = constrain_nonflex(model4, wm_cyc_start, wm_cyc_profile, duration, wm_tolerance, "wm")
        model4.update()

    if dw_cyc_start:
        # Dishwasher related variables
        dw_energy, _ = constrain_nonflex(model4, dw_cyc_start, dw_cyc_profile, duration, dw_tolerance, "dw")
        model4.update()

    # EV related variables
    ev_pos_energy, ev_neg_energy, _ = constrain_flex(model4, soc_init, soc_demand, soc_max, energy_rate, -energy_rate, ev_eff, ev_in, ev_out, duration, "ev")
    model4.update()

    # PV and BESS related variables
    battery_pos_energy, battery_neg_energy, _ = constrain_pv(model4, pv_battery_init, pv_battery_max, pv_battery_energy_rate, pv_battery_eff, duration, 'pv')
    model4.update()

    tot_demand = [] # add profiles of all cycles together to get the final wm power profile
    for t in range(duration):
        demand = gp.quicksum(wm_energy[i, t] for i in range(len(wm_cyc_start)))
        demand += gp.quicksum(dw_energy[i, t] for i in range(len(dw_cyc_start)))
        demand += ev_pos_energy[t] + ev_neg_energy[t] + critical_ini[t]
        demand += battery_pos_energy[t] + battery_neg_energy[t] - pv_ini[t] # the energy demand is the sum of the washing machine, dishwasher, critical appliances, EV and the battery
        model4.addConstr(demand >= 0, name=f"demand_nonneg_{t}") # ensure that the demand is non-negative
        tot_demand.append(demand) 

    # Now deal with the objective function considering the violation of power threshold
    excess = model4.addVars(duration,
                        lb=0,
                        vtype=gp.GRB.CONTINUOUS,
                        name="excess_kw")
    for t in range(duration):
        model4.addConstr(
            excess[t] >= tot_demand[t] - power_th/4,
            name=f"ex_def_{t}"
        )
        
    # binary flag: 1 if we exceed (excess>0), 0 otherwise
    penalty_flag = model4.addVars(duration,
                            vtype=gp.GRB.BINARY,
                            name="exceed_flag")

    # big‐M constraint: if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
    M = 1000.0   # “big‐M”: must exceed any possible (tot_demand*4 - P_th)
    for t in range(duration):
        # if excess[t]>0 ⇒ flag[t]=1, else flag[t] can be 0
        model4.addConstr(excess[t] <= M * penalty_flag[t],
                        name=f"flag_def_{t}")
        
    cost = gp.quicksum(
        (
        (1 - penalty_flag[t]) * price[t] 
        +  penalty_flag[t] * (price_penalty)
        )
        * tot_demand[t]
        for t in range(duration)
    )
    model4.setObjective(cost, gp.GRB.MINIMIZE)
    # Solve the model
    model4.optimize()

    # Check the optimization status
    if model4.status == gp.GRB.OPTIMAL:
        print("Optimal solution found.")
        print("Objective value (cost):", model4.objVal)
        cost_scenario4.append(model4.objVal)

        # Get the profiles of the appliances and store them in the data structure
        if wm_cyc_start:
            data_scenario4.loc[day*duration:(day+1)*duration-1, 'wm'] = np.array(get_profile(wm_energy, len(wm_cyc_start), duration, type='nonflex'))
        if dw_cyc_start:
            data_scenario4.loc[day*duration:(day+1)*duration-1, 'dw'] = np.array(get_profile(dw_energy, len(dw_cyc_start), duration, type='nonflex'))
        bess_pos_opt = get_profile(battery_pos_energy, duration, duration, type='flex')
        bess_neg_opt = get_profile(battery_neg_energy, duration, duration, type='flex')
        data_scenario4.loc[day*duration:(day+1)*duration-1, 'pv_bess'] = np.array(bess_pos_opt) + np.array(bess_neg_opt)

        ev_pos_opt = get_profile(ev_pos_energy, duration, duration, type='flex')
        ev_neg_opt = get_profile(ev_neg_energy, duration, duration, type='flex')
        data_scenario4.loc[day*duration:(day+1)*duration-1, 'ev'] = np.array(ev_pos_opt) + np.array(ev_neg_opt)
        data_scenario4.loc[day*duration:(day+1)*duration-1, 'critical'] = critical_ini

    else:
        print("No optimal solution found. Status code:", model4.status)
# Out:
# days: 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 713 rows, 1122 columns and 4106 nonzeros
# Model fingerprint: 0x24b5e757
# Model has 576 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 834 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [6e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [9e-03, 7e+01]
# Presolve removed 84 rows and 377 columns
# Presolve time: 0.01s
# Presolved: 977 rows, 1093 columns, 3215 nonzeros
# Variable types: 819 continuous, 274 integer (274 binary)
# Found heuristic solution: objective 0.4801682
#
# Root relaxation: objective -3.024303e+00, 763 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -3.02430    0  195    0.48017   -3.02430   730%     -    0s
# H    0     0                       0.3029450   -3.02430  1098%     -    0s
#      0     0   -0.14081    0   70    0.30295   -0.14081   146%     -    0s
#      0     0    0.29431    0   55    0.30295    0.29431  2.85%     -    0s
# H    0     0                       0.2996788    0.29431  1.79%     -    0s
#      0     0    0.29431    0   15    0.29968    0.29431  1.79%     -    0s
#      0     0    0.29759    0   12    0.29968    0.29759  0.70%     -    0s
#      0     0    0.29857    0    9    0.29968    0.29857  0.37%     -    0s
#      0     0    0.29857    0    9    0.29968    0.29857  0.37%     -    0s
#      0     0    0.29964    0    8    0.29968    0.29964  0.01%     -    0s
#      0     0    0.29964    0    5    0.29968    0.29964  0.01%     -    0s
#      0     0     cutoff    0         0.29968    0.29968  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 41
#   Cover: 1
#   Implied bound: 25
#   MIR: 38
#   Flow cover: 79
#   RLT: 42
#   Relax-and-lift: 1
#
# Explored 1 nodes (1698 simplex iterations) in 0.18 seconds (0.09 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 3: 0.299679 0.302945 0.480168
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.996787554526e-01, best bound 2.996787554526e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.29967875545263056
# days: 1
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 713 rows, 1122 columns and 4364 nonzeros
# Model fingerprint: 0xc16b6517
# Model has 576 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 834 continuous, 288 integer (288 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [2e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [2e-03, 7e+01]
# Presolve removed 28 rows and 325 columns
# Presolve time: 0.01s
# Presolved: 1054 rows, 1166 columns, 3719 nonzeros
# Variable types: 873 continuous, 293 integer (293 binary)
# Found heuristic solution: objective 0.6343952
#
# Root relaxation: objective -2.986980e+00, 1103 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -2.98698    0  234    0.63440   -2.98698   571%     -    0s
# H    0     0                       0.5966499   -2.98698   601%     -    0s
# H    0     0                       0.5826034   -2.98698   613%     -    0s
# H    0     0                       0.5721270   -0.32319   156%     -    0s
#      0     0   -0.32319    0  102    0.57213   -0.32319   156%     -    0s
#      0     0   -0.27839    0  103    0.57213   -0.27839   149%     -    0s
# H    0     0                       0.5248662   -0.27839   153%     -    0s
# H    0     0                       0.4581675    0.44361  3.18%     -    0s
#      0     0    0.44361    0    8    0.45817    0.44361  3.18%     -    0s
# H    0     0                       0.4547041    0.44688  1.72%     -    0s
#      0     0    0.44688    0    7    0.45470    0.44688  1.72%     -    0s
# H    0     0                       0.4472665    0.44727  0.00%     -    0s
#      0     0          -    0         0.44727    0.44727  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 40
#   Implied bound: 7
#   MIR: 34
#   Flow cover: 53
#   RLT: 70
#
# Explored 1 nodes (2485 simplex iterations) in 0.17 seconds (0.11 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 8: 0.447266 0.454704 0.458167 ... 0.634395
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.472664518283e-01, best bound 4.472664518283e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.44726645182825453
# days: 2
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 515 rows, 738 columns and 1763 nonzeros
# Model fingerprint: 0x8554cab4
# Model has 384 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 642 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [9e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [1e-02, 7e+01]
# Presolve added 48 rows and 0 columns
# Presolve removed 0 rows and 88 columns
# Presolve time: 0.01s
# Presolved: 856 rows, 943 columns, 2638 nonzeros
# Variable types: 714 continuous, 229 integer (229 binary)
# Found heuristic solution: objective 0.5084962
#
# Root relaxation: objective -2.993492e+00, 536 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -2.99349    0  186    0.50850   -2.99349   689%     -    0s
# H    0     0                       0.2718495   -2.99349  1201%     -    0s
# H    0     0                       0.2662781   -0.12703   148%     -    0s
#      0     0   -0.12703    0   45    0.26628   -0.12703   148%     -    0s
#      0     0    0.26138    0   39    0.26628    0.26138  1.84%     -    0s
# H    0     0                       0.2629672    0.26138  0.60%     -    0s
# H    0     0                       0.2629577    0.26138  0.60%     -    0s
#      0     0    0.26138    0    5    0.26296    0.26138  0.60%     -    0s
#
# Cutting planes:
#   Gomory: 57
#   Implied bound: 20
#   MIR: 36
#   Flow cover: 89
#   RLT: 20
#
# Explored 1 nodes (1317 simplex iterations) in 0.10 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 5: 0.262958 0.262967 0.266278 ... 0.508496
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.629577014740e-01, best bound 2.629432492401e-01, gap 0.0055%
# Optimal solution found.
# Objective value (cost): 0.26295770147397524
# days: 3
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 614 rows, 930 columns and 3152 nonzeros
# Model fingerprint: 0x859cbb69
# Model has 480 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 738 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [4e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [4e-03, 7e+01]
# Presolve removed 17 rows and 241 columns
# Presolve time: 0.01s
# Presolved: 913 rows, 1005 columns, 2827 nonzeros
# Variable types: 752 continuous, 253 integer (253 binary)
# Found heuristic solution: objective 0.4587945
#
# Root relaxation: objective -3.035586e+00, 585 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -3.03559    0  190    0.45879   -3.03559   762%     -    0s
# H    0     0                       0.2747345   -3.03559  1205%     -    0s
#      0     0   -0.08505    0   32    0.27473   -0.08505   131%     -    0s
#      0     0    0.02457    0   23    0.27473    0.02457  91.1%     -    0s
# H    0     0                       0.2710307    0.26846  0.95%     -    0s
#      0     0    0.26995    0    3    0.27103    0.26995  0.40%     -    0s
#      0     0    0.26995    0    3    0.27103    0.26995  0.40%     -    0s
# H    0     0                       0.2708809    0.27088  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 54
#   Implied bound: 2
#   MIR: 51
#   Flow cover: 45
#   RLT: 21
#
# Explored 1 nodes (1399 simplex iterations) in 0.12 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 4: 0.270881 0.271031 0.274735 0.458795
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.708808631914e-01, best bound 2.708808631914e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.2708808631914269
# days: 4
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 1013 rows, 1698 columns and 8331 nonzeros
# Model fingerprint: 0x36508c6f
# Model has 864 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 1122 continuous, 576 integer (576 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [5e-04, 8e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [6e-03, 7e+01]
# Presolve removed 291 rows and 850 columns
# Presolve time: 0.01s
# Presolved: 1134 rows, 1260 columns, 4170 nonzeros
# Variable types: 935 continuous, 325 integer (325 binary)
# Found heuristic solution: objective 0.7496537
# Found heuristic solution: objective 0.6964665
#
# Root relaxation: objective -2.683730e+00, 1269 iterations, 0.02 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -2.68373    0  220    0.69647   -2.68373   485%     -    0s
# H    0     0                       0.6555718   -2.68373   509%     -    0s
#      0     0    0.08065    0   95    0.65557    0.08065  87.7%     -    0s
# H    0     0                       0.6340760    0.11134  82.4%     -    0s
#      0     0    0.11860    0   86    0.63408    0.11860  81.3%     -    0s
#      0     0    0.59363    0   30    0.63408    0.59363  6.38%     -    0s
#      0     0    0.59686    0   23    0.63408    0.59686  5.87%     -    0s
# H    0     0                       0.6262180    0.59686  4.69%     -    0s
# H    0     0                       0.6145754    0.59686  2.88%     -    0s
#      0     0    0.60616    0   12    0.61458    0.60616  1.37%     -    0s
# H    0     0                       0.6107271    0.60618  0.75%     -    0s
#      0     0    0.60669    0   13    0.61073    0.60669  0.66%     -    0s
#      0     0    0.60761    0   17    0.61073    0.60761  0.51%     -    0s
#      0     0    0.61020    0   12    0.61073    0.61020  0.09%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 42
#   Implied bound: 19
#   MIR: 52
#   Flow cover: 69
#   RLT: 51
#   Relax-and-lift: 1
#
# Explored 1 nodes (2379 simplex iterations) in 0.24 seconds (0.15 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 7: 0.610727 0.614575 0.626218 ... 0.749654
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.107271015731e-01, best bound 6.107226587018e-01, gap 0.0007%
# Optimal solution found.
# Objective value (cost): 0.6107271015731297
# days: 5
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 814 rows, 1314 columns and 4960 nonzeros
# Model fingerprint: 0x005ca5a9
# Model has 672 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 930 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [6e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [1e-02, 7e+01]
# Presolve removed 109 rows and 473 columns
# Presolve time: 0.01s
# Presolved: 1094 rows, 1230 columns, 3786 nonzeros
# Variable types: 915 continuous, 315 integer (315 binary)
# Found heuristic solution: objective 0.6292782
# Found heuristic solution: objective 0.5725387
#
# Root relaxation: objective -2.881861e+00, 987 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -2.88186    0  219    0.57254   -2.88186   603%     -    0s
# H    0     0                       0.4723505   -2.88186   710%     -    0s
# H    0     0                       0.4681377   -0.05884   113%     -    0s
# H    0     0                       0.4646794   -0.05884   113%     -    0s
#      0     0   -0.05884    0   79    0.46468   -0.05884   113%     -    0s
# H    0     0                       0.4623190   -0.02821   106%     -    0s
#      0     0   -0.02417    0   75    0.46232   -0.02417   105%     -    0s
# H    0     0                       0.4470115    0.42996  3.81%     -    0s
# H    0     0                       0.4392350    0.42996  2.11%     -    0s
# H    0     0                       0.4371140    0.42996  1.64%     -    0s
#      0     0    0.42996    0   17    0.43711    0.42996  1.64%     -    0s
#      0     0    0.42996    0   14    0.43711    0.42996  1.64%     -    0s
#      0     0    0.43324    0   10    0.43711    0.43324  0.89%     -    0s
#      0     0    0.43625    0   12    0.43711    0.43625  0.20%     -    0s
#      0     0     cutoff    0         0.43711    0.43711  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 30
#   Cover: 2
#   Implied bound: 30
#   Clique: 1
#   MIR: 56
#   Flow cover: 51
#   RLT: 60
#   Relax-and-lift: 5
#   BQP: 1
#
# Explored 1 nodes (2135 simplex iterations) in 0.23 seconds (0.12 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 9: 0.437114 0.439235 0.447011 ... 0.629278
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.371139930748e-01, best bound 4.371139930748e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.4371139930747928
# days: 6
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10875H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 515 rows, 738 columns and 1763 nonzeros
# Model fingerprint: 0x91f627bd
# Model has 384 quadratic objective terms
# Model has 160 quadratic constraints
# Variable types: 642 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [9e-01, 1e+03]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [9e-04, 5e-02]
#   QObjective range [9e-02, 2e-01]
#   Bounds range     [1e+00, 7e+01]
#   RHS range        [1e-02, 7e+01]
# Presolve added 92 rows and 0 columns
# Presolve removed 0 rows and 36 columns
# Presolve time: 0.01s
# Presolved: 919 rows, 1014 columns, 2828 nonzeros
# Variable types: 766 continuous, 248 integer (248 binary)
# Found heuristic solution: objective 0.4779724
#
# Root relaxation: objective -2.994750e+00, 551 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -2.99475    0  177    0.47797   -2.99475   727%     -    0s
# H    0     0                       0.3013441   -2.99475  1094%     -    0s
# H    0     0                       0.2991521   -0.06536   122%     -    0s
#      0     0   -0.06536    0   41    0.29915   -0.06536   122%     -    0s
# H    0     0                       0.2941560   -0.03221   111%     -    0s
# H    0     0                       0.2939700    0.04060  86.2%     -    0s
#      0     0    0.04060    0   36    0.29397    0.04060  86.2%     -    0s
# H    0     0                       0.2925307    0.29233  0.07%     -    0s
#      0     0    0.29233    0    4    0.29253    0.29233  0.07%     -    0s
#      0     0    0.29233    0    4    0.29253    0.29233  0.07%     -    0s
#      0     0     cutoff    0         0.29253    0.29253  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 48
#   Implied bound: 17
#   MIR: 33
#   Flow cover: 74
#   RLT: 22
#
# Explored 1 nodes (1314 simplex iterations) in 0.10 seconds (0.05 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 6: 0.292531 0.29397 0.294156 ... 0.477972
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.925307329528e-01, best bound 2.925307329528e-01, gap 0.0000%
# Optimal solution found.
# Objective value (cost): 0.29253073295277

# %%
print(cost_scenario4)
data_scenario4.to_csv('output/winter_scenario4.csv', index=False)
# Out:
# [0.29967875545263056, 0.44726645182825453, 0.26295770147397524, 0.2708808631914269, 0.6107271015731297, 0.4371139930747928, 0.29253073295277]
